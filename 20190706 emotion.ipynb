# %%
from konlpy.tag import Okt
import json
import os
from pprint import pprint
import nltk
import numpy as np

# %%
# 파일 로드를 위한 함수
def read_data(filename):
    with open(filename, 'r', encoding='UTF8') as f:
        data = [line.split('\t') for line in f.read().splitlines()]
        # txt 파일의 헤더(id document label)는 제외하기
        data = data[1:]
    return data

train_data = read_data('ratings_train.txt')
test_data = read_data('ratings_test.txt')

# %%
# 1) morphs : 형태소 추출
# 2) pos : 품사 부착(Part-of-speech tagging)
# 3) nouns : 명사 추출
okt = Okt()

# %%
# 테스트
print(okt.pos(u'이 밤 그날의 반딧불을 당신의 창 가까이 보낼게요'))
# Out:
# [('이', 'Noun'), ('밤', 'Noun'), ('그날', 'Noun'), ('의', 'Josa'), ('반딧불', 'Noun'), ('을', 'Josa'), ('당신', 'Noun'), ('의', 'Josa'), ('창', 'Noun'), ('가까이', 'Noun'), ('보낼게요', 'Verb')]

# %%
def tokenize(doc):
    # norm은 정규화, stem은 근어로 표시하기를 나타냄
    return ['/'.join(t) for t in okt.pos(doc, norm=True, stem=True)]

# %%
if os.path.isfile('train_docs.json'):
    with open('train_docs.json', encoding='UTF8') as f:
        train_docs = json.load(f)
    with open('test_docs.json', encoding='UTF8') as f:
        test_docs = json.load(f)
else:
    train_docs = [(tokenize(row[1]), row[2]) for row in train_data]
    test_docs = [(tokenize(row[1]), row[2]) for row in test_data]
    # JSON 파일로 저장
    with open('train_docs.json', 'w', encoding="utf-8") as make_file:
        json.dump(train_docs, make_file, ensure_ascii=False, indent="\t")
    with open('test_docs.json', 'w', encoding="utf-8") as make_file:
        json.dump(test_docs, make_file, ensure_ascii=False, indent="\t")

# %%
pprint(train_docs[0])
# Out:
# [['아/Exclamation',
#   '더빙/Noun',
#   '../Punctuation',
#   '진짜/Noun',
#   '짜증나다/Adjective',
#   '목소리/Noun'],
#  '0']

# %%
tokens = [t for d in train_docs for t in d[0]]
print(len(tokens))
# Out:
# 2159921

# %%
text = nltk.Text(tokens, name='NMSC')

# 전체 토큰의 개수
print(len(text.tokens))

# 중복을 제외한 토큰의 개수
print(len(set(text.tokens)))

# 출현 빈도가 높은 상위 토큰 10개
pprint(text.vocab().most_common(10))
# Out:
# 2159921
# 49895
# [('./Punctuation', 67778),
#  ('영화/Noun', 50818),
#  ('하다/Verb', 41209),
#  ('이/Josa', 38540),
#  ('보다/Verb', 38538),
#  ('의/Josa', 30188),
#  ('../Punctuation', 29055),
#  ('가/Josa', 26627),
#  ('에/Josa', 26468),
#  ('을/Josa', 23118)]

# %%
# 시간이 꽤 걸립니다! 시간을 절약하고 싶으면 most_common의 매개변수를 줄여보세요.
# most_common(100) 의 수를 높일 수록 정확도가 올라갑니다.
selected_words = [f[0] for f in text.vocab().most_common(500)]

selected_words
# Out:
# ['./Punctuation',
#  '영화/Noun',
#  '하다/Verb',
#  '이/Josa',
#  '보다/Verb',
#  '의/Josa',
#  '../Punctuation',
#  '가/Josa',
#  '에/Josa',
#  '을/Josa',
#  '.../Punctuation',
#  '도/Josa',
#  '은/Josa',
#  '들/Suffix',
#  ',/Punctuation',
#  '는/Josa',
#  '없다/Adjective',
#  '를/Josa',
#  '있다/Adjective',
#  '좋다/Adjective',
#  '너무/Adverb',
#  '?/Punctuation',
#  '이/Determiner',
#  '재밌다/Adjective',
#  '정말/Noun',
#  '것/Noun',
#  '되다/Verb',
#  '!/Punctuation',
#  '진짜/Noun',
#  '같다/Adjective',
#  '적/Suffix',
#  '으로/Josa',
#  '이/Noun',
#  '점/Noun',
#  '아니다/Adjective',
#  '않다/Verb',
#  '로/Josa',
#  '에서/Josa',
#  '만/Josa',
#  '만들다/Verb',
#  '연기/Noun',
#  '나오다/Verb',
#  '평점/Noun',
#  '과/Josa',
#  '최고/Noun',
#  '~/Punctuation',
#  '한/Josa',
#  '이다/Verb',
#  '왜/Noun',
#  '스토리/Noun',
#  '생각/Noun',
#  '..../Punctuation',
#  '인/Josa',
#  '드라마/Noun',
#  '다/Adverb',
#  '다/Josa',
#  '이다/Josa',
#  '감동/Noun',
#  '사람/Noun',
#  '1/Number',
#  'ㅋㅋㅋ/KoreanParticle',
#  '보고/Noun',
#  '말/Noun',
#  '이렇다/Adjective',
#  '아깝다/Adjective',
#  '더/Noun',
#  '때/Noun',
#  'ㅋㅋ/KoreanParticle',
#  '내/Noun',
#  '배우/Noun',
#  '거/Noun',
#  '재미있다/Adjective',
#  '와/Josa',
#  '감독/Noun',
#  '뭐/Noun',
#  '재미/Noun',
#  '내용/Noun',
#  '고/Josa',
#  '그냥/Noun',
#  '못/VerbPrefix',
#  '주다/Verb',
#  '!!/Punctuation',
#  '까지/Josa',
#  '그/Noun',
#  '안/VerbPrefix',
#  '재미없다/Adjective',
#  '좀/Noun',
#  '게/Josa',
#  '자다/Verb',
#  '하고/Josa',
#  '지루하다/Adjective',
#  '쓰레기/Noun',
#  '시간/Noun',
#  '한/Determiner',
#  '가다/Verb',
#  '수/Noun',
#  '모르다/Verb',
#  '들다/Verb',
#  '그렇다/Adjective',
#  '나/Noun',
#  '싶다/Verb',
#  '아/Exclamation',
#  '10/Number',
#  '작품/Noun',
#  '사랑/Noun',
#  '알다/Verb',
#  '다시/Noun',
#  '하나/Noun',
#  '볼/Noun',
#  '마지막/Noun',
#  '잘/VerbPrefix',
#  'ㅋ/KoreanParticle',
#  '보다/Josa',
#  '요/Josa',
#  '오다/Verb',
#  '이다/Adjective',
#  '나/Josa',
#  '이렇게/Adverb',
#  '처음/Noun',
#  '완전/Noun',
#  '정도/Noun',
#  '2/Number',
#  '많다/Adjective',
#  '장면/Noun',
#  '액션/Noun',
#  '주인공/Noun',
#  '차다/Verb',
#  '안되다/Adjective',
#  '인데/Josa',
#  'ㅠㅠ/KoreanParticle',
#  '최악/Noun',
#  '나다/Verb',
#  '3/Number',
#  "'/Punctuation",
#  '돈/Noun',
#  '지금/Noun',
#  '이야기/Noun',
#  '중/Suffix',
#  '걸/Noun',
#  '별로/Noun',
#  '임/Noun',
#  '지/Josa',
#  '느낌/Noun',
#  '넘다/Verb',
#  '개/Noun',
#  '연출/Noun',
#  '라/Josa',
#  '끝/Noun',
#  '명작/Noun',
#  '좋아하다/Adjective',
#  '듯/Noun',
#  '그리고/Conjunction',
#  '역시/Noun',
#  '받다/Verb',
#  '남다/Verb',
#  '그/Determiner',
#  '이해/Noun',
#  '^^/Punctuation',
#  '이런/Modifier',
#  '!!!/Punctuation',
#  'ㅡㅡ/KoreanParticle',
#  '괜찮다/Adjective',
#  '이영화/Noun',
#  '라고/Josa',
#  '안/Noun',
#  '버리다/Verb',
#  '또/Noun',
#  '많이/Adverb',
#  '느끼다/Verb',
#  '여자/Noun',
#  '때문/Noun',
#  '먹다/Verb',
#  '내/Determiner',
#  '아름답다/Adjective',
#  '난/Noun',
#  '해주다/Verb',
#  '중/Noun',
#  '꼭/Noun',
#  '하/Suffix',
#  '편/Noun',
#  '이고/Josa',
#  '보기/Noun',
#  '에게/Josa',
#  '기억/Noun',
#  '결말/Noun',
#  '엔/Josa',
#  '어떻다/Adjective',
#  '이나/Josa',
#  'ㅎㅎ/KoreanParticle',
#  '랑/Josa',
#  '마음/Noun',
#  '인생/Noun',
#  '아쉽다/Adjective',
#  '서/Josa',
#  '소재/Noun',
#  '부터/Josa',
#  'ㅠ/KoreanParticle',
#  '뻔하다/Adjective',
#  '~~/Punctuation',
#  '끄다/Verb',
#  '애/Noun',
#  '면/Josa',
#  '못/Noun',
#  '보여주다/Verb',
#  '없이/Adverb',
#  '수준/Noun',
#  '어리다/Verb',
#  '재다/Verb',
#  '무섭다/Adjective',
#  '현실/Noun',
#  '맞다/Verb',
#  '한번/Noun',
#  '님/Suffix',
#  '가장/Noun',
#  '웃기다/Verb',
#  '반전/Noun',
#  '네/Josa',
#  '매력/Noun',
#  '전개/Noun',
#  '라는/Josa',
#  ';;/Punctuation',
#  '되어다/Verb',
#  '야/Josa',
#  '??/Punctuation',
#  '남자/Noun',
#  '한국/Noun',
#  '끝나다/Verb',
#  '가슴/Noun',
#  '인지/Josa',
#  '본/Modifier',
#  '낮다/Adjective',
#  '말다/Verb',
#  '슬프다/Adjective',
#  '높다/Adjective',
#  '죽다/Verb',
#  '저/Noun',
#  '음악/Noun',
#  '유치하다/Adjective',
#  '알/Noun',
#  '늘다/Verb',
#  '멋지다/Adjective',
#  '아이/Noun',
#  '성/Suffix',
#  '원작/Noun',
#  '아/Josa',
#  '줄/Noun',
#  '인가/Josa',
#  '하지만/Conjunction',
#  '인간/Noun',
#  '기/Modifier',
#  '솔직하다/Adjective',
#  '무슨/Noun',
#  '우리/Noun',
#  '냐/Josa',
#  '쓰다/Verb',
#  '추천/Noun',
#  '크다/Verb',
#  '게/Noun',
#  '함/Noun',
#  '눈물/Noun',
#  '씨/Suffix',
#  '만/Noun',
#  '살다/Verb',
#  '속/Noun',
#  '저/Determiner',
#  '내다/Verb',
#  '네/Suffix',
#  '야하다/Adjective',
#  '자체/Noun',
#  '번/Noun',
#  '도/Noun',
#  '허다/Verb',
#  '눈/Noun',
#  '찍다/Verb',
#  '지만/Josa',
#  '영/Modifier',
#  '짜증나다/Adjective',
#  '코미디/Noun',
#  '캐릭터/Noun',
#  '보이다/Verb',
#  '움/Noun',
#  '대박/Noun',
#  '뭔가/Noun',
#  '돼다/Verb',
#  '대한/Noun',
#  '전혀/Noun',
#  '그래도/Adverb',
#  '이상/Noun',
#  '연기력/Noun',
#  '이쁘다/Adjective',
#  '여운/Noun',
#  '이네/Josa',
#  '미치다/Adjective',
#  '굿/Noun',
#  '기대/Noun',
#  '건지다/Verb',
#  '별/Noun',
#  '모두/Noun',
#  '개봉/Noun',
#  '공감/Noun',
#  '일본/Noun',
#  '지다/Verb',
#  '근데/Adverb',
#  '기대하다/Adjective',
#  '중간/Noun',
#  '영상/Noun',
#  '아주/Noun',
#  ')/Punctuation',
#  '(/Punctuation',
#  '시리즈/Noun',
#  '부분/Noun',
#  '별/Modifier',
#  '모습/Noun',
#  '전/Noun',
#  '귀엽다/Adjective',
#  '계속/Noun',
#  '제목/Noun',
#  '에는/Josa',
#  '이랑/Josa',
#  '-/Punctuation',
#  '일/Modifier',
#  '시키다/Verb',
#  '요/Noun',
#  'ㅎ/KoreanParticle',
#  '치다/Verb',
#  '가족/Noun',
#  '화/Suffix',
#  ';/Punctuation',
#  '내내/Noun',
#  'OO/Alpha',
#  '뿐/Noun',
#  '급/Noun',
#  '보지/Noun',
#  '믿다/Verb',
#  '이라/Josa',
#  '진심/Noun',
#  '대/Modifier',
#  '실망/Noun',
#  '다른/Noun',
#  '몰입/Noun',
#  '후/Noun',
#  '두/Determiner',
#  '표현/Noun',
#  '처럼/Josa',
#  '밖에/Josa',
#  '기분/Noun',
#  '무엇/Noun',
#  '대단하다/Adjective',
#  'ㅜㅜ/KoreanParticle',
#  '작가/Noun',
#  '이/Suffix',
#  '잔잔하다/Adjective',
#  '떨어지다/Verb',
#  '위/Noun',
#  '이제/Noun',
#  '""""/Punctuation',
#  ',,/Punctuation',
#  '웃다/Verb',
#  '요즘/Noun',
#  '공포/Noun',
#  '용/Noun',
#  '스릴러/Noun',
#  '잼/Noun',
#  '빠지다/Verb',
#  '감/Noun',
#  '점도/Noun',
#  '4/Number',
#  '개인/Noun',
#  '긴장감/Noun',
#  'ㅡ/KoreanParticle',
#  '여/Modifier',
#  '이라는/Josa',
#  '모든/Noun',
#  '조금/Noun',
#  '대사/Noun',
#  '애니/Noun',
#  '이유/Noun',
#  '짜다/Verb',
#  '알바/Noun',
#  '분/Noun',
#  '제대로/Noun',
#  '삶/Noun',
#  '특히/Adverb',
#  '노래/Noun',
#  '건/Noun',
#  '욕/Noun',
#  '울다/Verb',
#  '짱/Noun',
#  '극장/Noun',
#  '한테/Josa',
#  '점수/Noun',
#  '시작/Noun',
#  '0/Number',
#  '막장/Noun',
#  '이상하다/Adjective',
#  '기/Noun',
#  '나름/Noun',
#  '예쁘다/Adjective',
#  '...../Punctuation',
#  '노잼/Noun',
#  '깊다/Adjective',
#  '제일/Noun',
#  '차라리/Noun',
#  '놈/Noun',
#  '친구/Noun',
#  '오랜/Modifier',
#  '느껴지다/Verb',
#  '제/Noun',
#  '해보다/Verb',
#  '에도/Josa',
#  '당시/Noun',
#  '영화로/Noun',
#  '어설프다/Adjective',
#  '류/Noun',
#  '절대/Noun',
#  '의미/Noun',
#  '빼다/Verb',
#  '따뜻하다/Adjective',
#  '잇다/Verb',
#  '세상/Noun',
#  '위해/Noun',
#  '력/Suffix',
#  '미국/Noun',
#  '♥/Foreign',
#  '찾다/Verb',
#  '아직도/Adverb',
#  '훌륭하다/Adjective',
#  '"""/Punctuation',
#  '도대체/Noun',
#  '이지/Josa',
#  '이라고/Josa',
#  '앞/Noun',
#  '공포영화/Noun',
#  '연/Modifier',
#  '걍/Adverb',
#  '웃음/Noun',
#  '로/Noun',
#  '생각나다/Verb',
#  '설정/Noun',
#  '그리다/Verb',
#  '대다/Verb',
#  '7/Number',
#  '죽이다/Verb',
#  '수작/Noun',
#  '힘들다/Adjective',
#  '물/Noun',
#  '의/Noun',
#  '써다/Verb',
#  '일/Noun',
#  '다르다/Adjective',
#  '뭘/Noun',
#  '우리나라/Noun',
#  '초반/Noun',
#  '싫다/Adjective',
#  '남/Noun',
#  'OOO/Alpha',
#  '출연/Noun',
#  '명/Noun',
#  '제/Modifier',
#  '추억/Noun',
#  '사실/Noun',
#  '필요없다/Adjective',
#  '답답하다/Adjective',
#  '5/Number',
#  '엄청/Adverb',
#  '따다/Verb',
#  '장난/Noun',
#  '이야/Josa',
#  '딱/Adverb',
#  '해/Noun',
#  '지루함/Noun',
#  '한국영/Noun',
#  '니/Josa',
#  '멋있다/Adjective',
#  '마다/Josa',
#  '놓다/Verb',
#  '가지/Noun',
#  '이란/Josa',
#  '시나리오/Noun',
#  '소리/Noun',
#  '신선하다/Adjective',
#  '분위기/Noun',
#  '아프다/Adjective',
#  '팬/Noun',
#  '관객/Noun',
#  '시대/Noun',
#  '대/Suffix',
#  '뭔/Modifier',
#  '어이없다/Adjective',
#  '졸작/Noun',
#  '살/Noun',
#  '자신/Noun',
#  '잊다/Verb',
#  '이딴/Modifier',
#  '나쁘다/Adjective',
#  '감정/Noun',
#  '최고다/Noun',
#  '더럽다/Adjective',
#  '봄/Noun',
#  '기다/Verb']

# %%
def term_frequency(doc):
    return [doc.count(word) for word in selected_words]

train_x = [term_frequency(d) for d, _ in train_docs]
test_x = [term_frequency(d) for d, _ in test_docs]
train_y = [c for _, c in train_docs]
test_y = [c for _, c in test_docs]

x_train = np.asarray(train_x).astype('float32')
x_test = np.asarray(test_x).astype('float32')
y_train = np.asarray(train_y).astype('float32')
y_test = np.asarray(test_y).astype('float32')

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras import losses
from keras import metrics
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=optimizers.RMSprop(lr=0.001), loss=losses.binary_crossentropy, metrics=[metrics.binary_accuracy])

model.fit(x_train, y_train, epochs=10, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# WARNING:tensorflow:From c:\users\2qqns\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From c:\users\2qqns\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 150000/150000 [==============================] - 2s 15us/step - loss: 0.4605 - binary_accuracy: 0.7814
# Epoch 2/10
# 150000/150000 [==============================] - 2s 12us/step - loss: 0.4137 - binary_accuracy: 0.8029
# Epoch 3/10
# 150000/150000 [==============================] - 2s 12us/step - loss: 0.4011 - binary_accuracy: 0.8100
# Epoch 4/10
# 150000/150000 [==============================] - 2s 12us/step - loss: 0.3906 - binary_accuracy: 0.8162
# Epoch 5/10
# 150000/150000 [==============================] - 2s 11us/step - loss: 0.3812 - binary_accuracy: 0.8220
# Epoch 6/10
# 150000/150000 [==============================] - 2s 11us/step - loss: 0.3725 - binary_accuracy: 0.8268
# Epoch 7/10
# 150000/150000 [==============================] - 2s 11us/step - loss: 0.3642 - binary_accuracy: 0.8318
# Epoch 8/10
# 150000/150000 [==============================] - 2s 11us/step - loss: 0.3564 - binary_accuracy: 0.8359
# Epoch 9/10
# 150000/150000 [==============================] - 2s 11us/step - loss: 0.3492 - binary_accuracy: 0.8404
# Epoch 10/10
# 150000/150000 [==============================] - 2s 11us/step - loss: 0.3422 - binary_accuracy: 0.8443
# 50000/50000 [==============================] - 2s 31us/step

# %%
def predict_pos_neg(review):
    token = tokenize(review)
    tf = term_frequency(token)
    data = np.expand_dims(np.asarray(tf).astype('float32'), axis=0)
    score = float(model.predict(data))
    if(score > 0.5):
        print("[{}]는 {:.2f}% 긍정\n".format(review, score * 100))
    else:
        print("[{}]는 {:.2f}% 부정\n".format(review, (1 - score) * 100))


# 테스트
predict_pos_neg("할줄아는거 없고 해낼 자신도 없는데 한심하고 착잡하다")
predict_pos_neg("슬픈 영화 보고 그냥 펑펑 울고 싶은데 추천 좀 해주세요")
predict_pos_neg("겨드랑이에서 삼겹살 냄새 나는듯")
predict_pos_neg("진짜 너무 심심한데 놀아줄사람")
predict_pos_neg("튜터링 돈 언제 주냐 ㅋㅋㅋㅋㅋ")
predict_pos_neg("노트북 브랜드 추천점")
# Out:
# [할줄아는거 없고 해낼 자신도 없는데 한심하고 착잡하다]는 90.70% 부정
#
# [슬픈 영화 보고 그냥 펑펑 울고 싶은데 추천 좀 해주세요]는 76.41% 긍정
#
# [겨드랑이에서 삼겹살 냄새 나는듯]는 58.99% 긍정
#
# [진짜 너무 심심한데 놀아줄사람]는 66.98% 긍정
#
# [튜터링 돈 언제 주냐 ㅋㅋㅋㅋㅋ]는 95.86% 부정
#
# [노트북 브랜드 추천점]는 65.47% 긍정
