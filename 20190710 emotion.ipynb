# %%
from konlpy.tag import Okt
import json
import os
from pprint import pprint
import nltk
import numpy as np

# %%
# 파일 로드를 위한 함수
def read_data(filename):
    with open(filename, 'r', encoding='UTF8') as f:
        data = [line.split('\t') for line in f.read().splitlines()]
        # txt 파일의 헤더(id document label)는 제외하기
        data = data[1:]
    return data

train_data = read_data('ratings_train.txt') #데이터불러오기
test_data = read_data('ratings_test.txt') #데이터불러오기

# %%
# 1) morphs : 형태소 추출
# 2) pos : 품사 부착(Part-of-speech tagging)
# 3) nouns : 명사 추출
okt = Okt()

# %%
# 테스트
print(okt.pos(u'이 밤 그날의 반딧불을 당신의 창 가까이 보낼게요'))
# Out:
# [('이', 'Noun'), ('밤', 'Noun'), ('그날', 'Noun'), ('의', 'Josa'), ('반딧불', 'Noun'), ('을', 'Josa'), ('당신', 'Noun'), ('의', 'Josa'), ('창', 'Noun'), ('가까이', 'Noun'), ('보낼게요', 'Verb')]

# %%
def tokenize(doc):
    # norm은 정규화, stem은 근어로 표시하기를 나타냄
    return ['/'.join(t) for t in okt.pos(doc, norm=True, stem=True)]

# %%
if os.path.isfile('train_docs.json'): #파일이존재하면
    with open('train_docs.json', encoding='UTF8') as f:
        train_docs = json.load(f)
    with open('test_docs.json', encoding='UTF8') as f:
        test_docs = json.load(f)
else:
    train_docs = [(tokenize(row[1]), row[2]) for row in train_data]
    test_docs = [(tokenize(row[1]), row[2]) for row in test_data]
    # JSON 파일로 저장
    with open('train_docs.json', 'w', encoding="utf-8") as make_file:
        json.dump(train_docs, make_file, ensure_ascii=False, indent="\t")
    with open('test_docs.json', 'w', encoding="utf-8") as make_file:
        json.dump(test_docs, make_file, ensure_ascii=False, indent="\t")

# %%
pprint(train_docs[0]) #tokenize된 학습데이터 첫번째 테스트출력
# Out:
# [['아/Exclamation',
#   '더빙/Noun',
#   '../Punctuation',
#   '진짜/Noun',
#   '짜증나다/Adjective',
#   '목소리/Noun'],
#  '0']

# %%
tokens = [t for d in train_docs for t in d[0]]
print(len(tokens)) #학습데이터의 총 토큰개수
# Out:
# 2159921

# %%
print(type(tokens)) #tokens의 타입은 list. 토큰들이 들어가있다.
# Out:
# <class 'list'>

# %%
text = nltk.Text(tokens, name='NMSC')

# 전체 토큰의 개수
print(len(text.tokens))

# 중복을 제외한 토큰의 개수
print(len(set(text.tokens)))

# 출현 빈도가 높은 상위 토큰 10개
pprint(text.vocab().most_common(10))
# Out:
# 2159921
# 49895
# [('./Punctuation', 67778),
#  ('영화/Noun', 50818),
#  ('하다/Verb', 41209),
#  ('이/Josa', 38540),
#  ('보다/Verb', 38538),
#  ('의/Josa', 30188),
#  ('../Punctuation', 29055),
#  ('가/Josa', 26627),
#  ('에/Josa', 26468),
#  ('을/Josa', 23118)]

# %%
# 출현빈도가 높은 상위 토큰을 몇개 가져올건지 정하여 정확도높이기
# 시간이 꽤 걸립니다! 시간을 절약하고 싶으면 most_common의 매개변수를 줄여보세요.
# most_common(100) 의 수를 높일 수록 정확도가 올라갑니다.
selected_words = [f[0] for f in text.vocab().most_common(1000)]

selected_words
# Out:
# ['./Punctuation',
#  '영화/Noun',
#  '하다/Verb',
#  '이/Josa',
#  '보다/Verb',
#  '의/Josa',
#  '../Punctuation',
#  '가/Josa',
#  '에/Josa',
#  '을/Josa',
#  '.../Punctuation',
#  '도/Josa',
#  '은/Josa',
#  '들/Suffix',
#  ',/Punctuation',
#  '는/Josa',
#  '없다/Adjective',
#  '를/Josa',
#  '있다/Adjective',
#  '좋다/Adjective',
#  '너무/Adverb',
#  '?/Punctuation',
#  '이/Determiner',
#  '재밌다/Adjective',
#  '정말/Noun',
#  '것/Noun',
#  '되다/Verb',
#  '!/Punctuation',
#  '진짜/Noun',
#  '같다/Adjective',
#  '적/Suffix',
#  '으로/Josa',
#  '이/Noun',
#  '점/Noun',
#  '아니다/Adjective',
#  '않다/Verb',
#  '로/Josa',
#  '에서/Josa',
#  '만/Josa',
#  '만들다/Verb',
#  '연기/Noun',
#  '나오다/Verb',
#  '평점/Noun',
#  '과/Josa',
#  '최고/Noun',
#  '~/Punctuation',
#  '한/Josa',
#  '이다/Verb',
#  '왜/Noun',
#  '스토리/Noun',
#  '생각/Noun',
#  '..../Punctuation',
#  '인/Josa',
#  '드라마/Noun',
#  '다/Adverb',
#  '다/Josa',
#  '이다/Josa',
#  '감동/Noun',
#  '사람/Noun',
#  '1/Number',
#  'ㅋㅋㅋ/KoreanParticle',
#  '보고/Noun',
#  '말/Noun',
#  '이렇다/Adjective',
#  '아깝다/Adjective',
#  '더/Noun',
#  '때/Noun',
#  'ㅋㅋ/KoreanParticle',
#  '내/Noun',
#  '배우/Noun',
#  '거/Noun',
#  '재미있다/Adjective',
#  '와/Josa',
#  '감독/Noun',
#  '뭐/Noun',
#  '재미/Noun',
#  '내용/Noun',
#  '고/Josa',
#  '그냥/Noun',
#  '못/VerbPrefix',
#  '주다/Verb',
#  '!!/Punctuation',
#  '까지/Josa',
#  '그/Noun',
#  '안/VerbPrefix',
#  '재미없다/Adjective',
#  '좀/Noun',
#  '게/Josa',
#  '자다/Verb',
#  '하고/Josa',
#  '지루하다/Adjective',
#  '쓰레기/Noun',
#  '시간/Noun',
#  '한/Determiner',
#  '가다/Verb',
#  '수/Noun',
#  '모르다/Verb',
#  '들다/Verb',
#  '그렇다/Adjective',
#  '나/Noun',
#  '싶다/Verb',
#  '아/Exclamation',
#  '10/Number',
#  '작품/Noun',
#  '사랑/Noun',
#  '알다/Verb',
#  '다시/Noun',
#  '하나/Noun',
#  '볼/Noun',
#  '마지막/Noun',
#  '잘/VerbPrefix',
#  'ㅋ/KoreanParticle',
#  '보다/Josa',
#  '요/Josa',
#  '오다/Verb',
#  '이다/Adjective',
#  '나/Josa',
#  '이렇게/Adverb',
#  '처음/Noun',
#  '완전/Noun',
#  '정도/Noun',
#  '2/Number',
#  '많다/Adjective',
#  '장면/Noun',
#  '액션/Noun',
#  '주인공/Noun',
#  '차다/Verb',
#  '안되다/Adjective',
#  '인데/Josa',
#  'ㅠㅠ/KoreanParticle',
#  '최악/Noun',
#  '나다/Verb',
#  '3/Number',
#  "'/Punctuation",
#  '돈/Noun',
#  '지금/Noun',
#  '이야기/Noun',
#  '중/Suffix',
#  '걸/Noun',
#  '별로/Noun',
#  '임/Noun',
#  '지/Josa',
#  '느낌/Noun',
#  '넘다/Verb',
#  '개/Noun',
#  '연출/Noun',
#  '라/Josa',
#  '끝/Noun',
#  '명작/Noun',
#  '좋아하다/Adjective',
#  '듯/Noun',
#  '그리고/Conjunction',
#  '역시/Noun',
#  '받다/Verb',
#  '남다/Verb',
#  '그/Determiner',
#  '이해/Noun',
#  '^^/Punctuation',
#  '이런/Modifier',
#  '!!!/Punctuation',
#  'ㅡㅡ/KoreanParticle',
#  '괜찮다/Adjective',
#  '이영화/Noun',
#  '라고/Josa',
#  '안/Noun',
#  '버리다/Verb',
#  '또/Noun',
#  '많이/Adverb',
#  '느끼다/Verb',
#  '여자/Noun',
#  '때문/Noun',
#  '먹다/Verb',
#  '내/Determiner',
#  '아름답다/Adjective',
#  '난/Noun',
#  '해주다/Verb',
#  '중/Noun',
#  '꼭/Noun',
#  '하/Suffix',
#  '편/Noun',
#  '이고/Josa',
#  '보기/Noun',
#  '에게/Josa',
#  '기억/Noun',
#  '결말/Noun',
#  '엔/Josa',
#  '어떻다/Adjective',
#  '이나/Josa',
#  'ㅎㅎ/KoreanParticle',
#  '랑/Josa',
#  '마음/Noun',
#  '인생/Noun',
#  '아쉽다/Adjective',
#  '서/Josa',
#  '소재/Noun',
#  '부터/Josa',
#  'ㅠ/KoreanParticle',
#  '뻔하다/Adjective',
#  '~~/Punctuation',
#  '끄다/Verb',
#  '애/Noun',
#  '면/Josa',
#  '못/Noun',
#  '보여주다/Verb',
#  '없이/Adverb',
#  '수준/Noun',
#  '어리다/Verb',
#  '재다/Verb',
#  '무섭다/Adjective',
#  '현실/Noun',
#  '맞다/Verb',
#  '한번/Noun',
#  '님/Suffix',
#  '가장/Noun',
#  '웃기다/Verb',
#  '반전/Noun',
#  '네/Josa',
#  '매력/Noun',
#  '전개/Noun',
#  '라는/Josa',
#  ';;/Punctuation',
#  '되어다/Verb',
#  '야/Josa',
#  '??/Punctuation',
#  '남자/Noun',
#  '한국/Noun',
#  '끝나다/Verb',
#  '가슴/Noun',
#  '인지/Josa',
#  '본/Modifier',
#  '낮다/Adjective',
#  '말다/Verb',
#  '슬프다/Adjective',
#  '높다/Adjective',
#  '죽다/Verb',
#  '저/Noun',
#  '음악/Noun',
#  '유치하다/Adjective',
#  '알/Noun',
#  '늘다/Verb',
#  '멋지다/Adjective',
#  '아이/Noun',
#  '성/Suffix',
#  '원작/Noun',
#  '아/Josa',
#  '줄/Noun',
#  '인가/Josa',
#  '하지만/Conjunction',
#  '인간/Noun',
#  '기/Modifier',
#  '솔직하다/Adjective',
#  '무슨/Noun',
#  '우리/Noun',
#  '냐/Josa',
#  '쓰다/Verb',
#  '추천/Noun',
#  '크다/Verb',
#  '게/Noun',
#  '함/Noun',
#  '눈물/Noun',
#  '씨/Suffix',
#  '만/Noun',
#  '살다/Verb',
#  '속/Noun',
#  '저/Determiner',
#  '내다/Verb',
#  '네/Suffix',
#  '야하다/Adjective',
#  '자체/Noun',
#  '번/Noun',
#  '도/Noun',
#  '허다/Verb',
#  '눈/Noun',
#  '찍다/Verb',
#  '지만/Josa',
#  '영/Modifier',
#  '짜증나다/Adjective',
#  '코미디/Noun',
#  '캐릭터/Noun',
#  '보이다/Verb',
#  '움/Noun',
#  '대박/Noun',
#  '뭔가/Noun',
#  '돼다/Verb',
#  '대한/Noun',
#  '전혀/Noun',
#  '그래도/Adverb',
#  '이상/Noun',
#  '연기력/Noun',
#  '이쁘다/Adjective',
#  '여운/Noun',
#  '이네/Josa',
#  '미치다/Adjective',
#  '굿/Noun',
#  '기대/Noun',
#  '건지다/Verb',
#  '별/Noun',
#  '모두/Noun',
#  '개봉/Noun',
#  '공감/Noun',
#  '일본/Noun',
#  '지다/Verb',
#  '근데/Adverb',
#  '기대하다/Adjective',
#  '중간/Noun',
#  '영상/Noun',
#  '아주/Noun',
#  ')/Punctuation',
#  '(/Punctuation',
#  '시리즈/Noun',
#  '부분/Noun',
#  '별/Modifier',
#  '모습/Noun',
#  '전/Noun',
#  '귀엽다/Adjective',
#  '계속/Noun',
#  '제목/Noun',
#  '에는/Josa',
#  '이랑/Josa',
#  '-/Punctuation',
#  '일/Modifier',
#  '시키다/Verb',
#  '요/Noun',
#  'ㅎ/KoreanParticle',
#  '치다/Verb',
#  '가족/Noun',
#  '화/Suffix',
#  ';/Punctuation',
#  '내내/Noun',
#  'OO/Alpha',
#  '뿐/Noun',
#  '급/Noun',
#  '보지/Noun',
#  '믿다/Verb',
#  '이라/Josa',
#  '진심/Noun',
#  '대/Modifier',
#  '실망/Noun',
#  '다른/Noun',
#  '몰입/Noun',
#  '후/Noun',
#  '두/Determiner',
#  '표현/Noun',
#  '처럼/Josa',
#  '밖에/Josa',
#  '기분/Noun',
#  '무엇/Noun',
#  '대단하다/Adjective',
#  'ㅜㅜ/KoreanParticle',
#  '작가/Noun',
#  '이/Suffix',
#  '잔잔하다/Adjective',
#  '떨어지다/Verb',
#  '위/Noun',
#  '이제/Noun',
#  '""""/Punctuation',
#  ',,/Punctuation',
#  '웃다/Verb',
#  '요즘/Noun',
#  '공포/Noun',
#  '용/Noun',
#  '스릴러/Noun',
#  '잼/Noun',
#  '빠지다/Verb',
#  '감/Noun',
#  '점도/Noun',
#  '4/Number',
#  '개인/Noun',
#  '긴장감/Noun',
#  'ㅡ/KoreanParticle',
#  '여/Modifier',
#  '이라는/Josa',
#  '모든/Noun',
#  '조금/Noun',
#  '대사/Noun',
#  '애니/Noun',
#  '이유/Noun',
#  '짜다/Verb',
#  '알바/Noun',
#  '분/Noun',
#  '제대로/Noun',
#  '삶/Noun',
#  '특히/Adverb',
#  '노래/Noun',
#  '건/Noun',
#  '욕/Noun',
#  '울다/Verb',
#  '짱/Noun',
#  '극장/Noun',
#  '한테/Josa',
#  '점수/Noun',
#  '시작/Noun',
#  '0/Number',
#  '막장/Noun',
#  '이상하다/Adjective',
#  '기/Noun',
#  '나름/Noun',
#  '예쁘다/Adjective',
#  '...../Punctuation',
#  '노잼/Noun',
#  '깊다/Adjective',
#  '제일/Noun',
#  '차라리/Noun',
#  '놈/Noun',
#  '친구/Noun',
#  '오랜/Modifier',
#  '느껴지다/Verb',
#  '제/Noun',
#  '해보다/Verb',
#  '에도/Josa',
#  '당시/Noun',
#  '영화로/Noun',
#  '어설프다/Adjective',
#  '류/Noun',
#  '절대/Noun',
#  '의미/Noun',
#  '빼다/Verb',
#  '따뜻하다/Adjective',
#  '잇다/Verb',
#  '세상/Noun',
#  '위해/Noun',
#  '력/Suffix',
#  '미국/Noun',
#  '♥/Foreign',
#  '찾다/Verb',
#  '아직도/Adverb',
#  '훌륭하다/Adjective',
#  '"""/Punctuation',
#  '도대체/Noun',
#  '이지/Josa',
#  '이라고/Josa',
#  '앞/Noun',
#  '공포영화/Noun',
#  '연/Modifier',
#  '걍/Adverb',
#  '웃음/Noun',
#  '로/Noun',
#  '생각나다/Verb',
#  '설정/Noun',
#  '그리다/Verb',
#  '대다/Verb',
#  '7/Number',
#  '죽이다/Verb',
#  '수작/Noun',
#  '힘들다/Adjective',
#  '물/Noun',
#  '의/Noun',
#  '써다/Verb',
#  '일/Noun',
#  '다르다/Adjective',
#  '뭘/Noun',
#  '우리나라/Noun',
#  '초반/Noun',
#  '싫다/Adjective',
#  '남/Noun',
#  'OOO/Alpha',
#  '출연/Noun',
#  '명/Noun',
#  '제/Modifier',
#  '추억/Noun',
#  '사실/Noun',
#  '필요없다/Adjective',
#  '답답하다/Adjective',
#  '5/Number',
#  '엄청/Adverb',
#  '따다/Verb',
#  '장난/Noun',
#  '이야/Josa',
#  '딱/Adverb',
#  '해/Noun',
#  '지루함/Noun',
#  '한국영/Noun',
#  '니/Josa',
#  '멋있다/Adjective',
#  '마다/Josa',
#  '놓다/Verb',
#  '가지/Noun',
#  '이란/Josa',
#  '시나리오/Noun',
#  '소리/Noun',
#  '신선하다/Adjective',
#  '분위기/Noun',
#  '아프다/Adjective',
#  '팬/Noun',
#  '관객/Noun',
#  '시대/Noun',
#  '대/Suffix',
#  '뭔/Modifier',
#  '어이없다/Adjective',
#  '졸작/Noun',
#  '살/Noun',
#  '자신/Noun',
#  '잊다/Verb',
#  '이딴/Modifier',
#  '나쁘다/Adjective',
#  '감정/Noun',
#  '최고다/Noun',
#  '더럽다/Adjective',
#  '봄/Noun',
#  '기다/Verb',
#  '접/Noun',
#  '오늘/Noun',
#  '안타깝다/Adjective',
#  '영화관/Noun',
#  '이지만/Josa',
#  '엄마/Noun',
#  '엔딩/Noun',
#  '결국/Adverb',
#  '부족하다/Adjective',
#  '정신/Noun',
#  '스럽다/Adjective',
#  '제발/Noun',
#  '인상/Noun',
#  '배우다/Verb',
#  '문제/Noun',
#  '포스터/Noun',
#  '더빙/Noun',
#  '캐스팅/Noun',
#  '준/Noun',
#  '라면/Noun',
#  '평가/Noun',
#  '코믹/Noun',
#  '~~~/Punctuation',
#  '아무리/Adverb',
#  '엉/Exclamation',
#  '니까/Josa',
#  '얼마나/Noun',
#  '음/Noun',
#  '그저/Adverb',
#  '애니메이션/Noun',
#  '함께/Adverb',
#  '시/Modifier',
#  '어색하다/Adjective',
#  '서다/Verb',
#  '!!!!/Punctuation',
#  'ㅠㅠㅠ/KoreanParticle',
#  '몰입도/Noun',
#  '전/Modifier',
#  '킬링타임/Noun',
#  '망하다/Adjective',
#  '비다/Verb',
#  '자/Suffix',
#  '강추/Noun',
#  '티비/Noun',
#  '배경/Noun',
#  '적다/Verb',
#  '유쾌하다/Adjective',
#  '8/Number',
#  '대해/Noun',
#  '쓸다/Verb',
#  '살리다/Verb',
#  '두다/Verb',
#  '뒤/Noun',
#  '든/Josa',
#  '맘/Noun',
#  '지/Modifier',
#  '스릴/Noun',
#  '만화/Noun',
#  '충격/Noun',
#  '개연/Noun',
#  '질/Noun',
#  '얘기/Noun',
#  '를/Noun',
#  '진부하다/Adjective',
#  '나가다/Verb',
#  '그렇게/Adverb',
#  '완벽하다/Adjective',
#  '전쟁/Noun',
#  '책/Noun',
#  '즐겁다/Adjective',
#  '머리/Noun',
#  '구성/Noun',
#  '데/Noun',
#  'ㅜ/KoreanParticle',
#  '예술/Noun',
#  '갈수록/Noun',
#  '어디/Noun',
#  '놀라다/Verb',
#  '얼굴/Noun',
#  '보단/Josa',
#  '매우/Noun',
#  '후회/Noun',
#  '하/Exclamation',
#  '웃기/Noun',
#  '이름/Noun',
#  '여/Josa',
#  '너무나/Adverb',
#  '읽다/Verb',
#  '기도/Noun',
#  '9/Number',
#  '머/Noun',
#  '옛날/Noun',
#  '어울리다/Verb',
#  '같이/Adverb',
#  '적/Noun',
#  '들이다/Verb',
#  '행복하다/Adjective',
#  '대/Foreign',
#  '영화인/Noun',
#  '장르/Noun',
#  '집중/Noun',
#  '꽤/Noun',
#  '이후/Noun',
#  '집/Noun',
#  '은/Noun',
#  '주연/Noun',
#  '새롭다/Adjective',
#  '존나/Noun',
#  '그래서/Adverb',
#  '억지/Noun',
#  '멀다/Adjective',
#  '건가/Noun',
#  '???/Punctuation',
#  '누구/Noun',
#  '다큐/Noun',
#  '상황/Noun',
#  '날/Noun',
#  '진/Noun',
#  '만/Suffix',
#  'ㅎㅎㅎ/KoreanParticle',
#  '비/Noun',
#  '이리/Adverb',
#  '언제/Noun',
#  '그것/Noun',
#  '+/Punctuation',
#  '작/Modifier',
#  '글/Noun',
#  '짜증/Noun',
#  ',,,/Punctuation',
#  '씬/Noun',
#  '시즌/Noun',
#  '아직/Adverb',
#  '충분하다/Adjective',
#  '예전/Noun',
#  '역사/Noun',
#  '후반/Noun',
#  '다운/Noun',
#  '밉다/Adjective',
#  '생기다/Verb',
#  'B/Alpha',
#  '극/Modifier',
#  '걸작/Noun',
#  '식/Suffix',
#  '누가/Noun',
#  '여기/Noun',
#  '불쌍하다/Adjective',
#  '궁금하다/Adjective',
#  '두/Noun',
#  '약간/Noun',
#  '급/Suffix',
#  '자기/Noun',
#  '실화/Noun',
#  '니/Noun',
#  '그나마/Adverb',
#  '분들/Suffix',
#  '소름/Noun',
#  '인물/Noun',
#  '발연기/Noun',
#  '아무/Modifier',
#  '해도/Noun',
#  '심하다/Adjective',
#  '등/Noun',
#  '그대로/Noun',
#  '훨씬/Adverb',
#  '드리다/Verb',
#  '잔인하다/Adjective',
#  '방송/Noun',
#  '시절/Noun',
#  '~!/Punctuation',
#  '작/Noun',
#  '부/Noun',
#  '주/Modifier',
#  '네/Determiner',
#  '비디오/Noun',
#  '자/Noun',
#  '순수하다/Adjective',
#  '만점/Noun',
#  '비슷하다/Adjective',
#  '한마디/Noun',
#  '대체/Noun',
#  '아들/Noun',
#  '다음/Noun',
#  '간만/Noun',
#  '소설/Noun',
#  '로맨스/Noun',
#  'CG/Alpha',
#  '휴/Exclamation',
#  '사회/Noun',
#  '보/Noun',
#  '어렵다/Adjective',
#  '판/Noun',
#  '비교/Noun',
#  '초딩/Noun',
#  '필요하다/Adjective',
#  '6/Number',
#  '쉬다/Verb',
#  '감성/Noun',
#  '네이버/Noun',
#  '꿈/Noun',
#  '남기다/Verb',
#  '몇/Modifier',
#  '따르다/Verb',
#  '오/Modifier',
#  '여배우/Noun',
#  '전체/Noun',
#  '타다/Verb',
#  '만나다/Verb',
#  '떠나다/Verb',
#  '그런/Modifier',
#  '여주/Noun',
#  '상당하다/Adjective',
#  '라도/Josa',
#  '뿐/Suffix',
#  '사랑스럽다/Adjective',
#  '코/Noun',
#  '이르다/Verb',
#  '성룡/Noun',
#  '나이/Noun',
#  '당하다/Adjective',
#  '무슨/Modifier',
#  ';;;/Punctuation',
#  '이라도/Josa',
#  '굉장하다/Adjective',
#  '편이/Noun',
#  '너/Noun',
#  '혼자/Noun',
#  '터지다/Verb',
#  '반/Modifier',
#  '삼류/Noun',
#  '순간/Noun',
#  '죠/Josa',
#  '감사하다/Verb',
#  '년/Noun',
#  '교훈/Noun',
#  '굳다/Adjective',
#  '돌리다/Verb',
#  '보다는/Josa',
#  'ㅉㅉ/KoreanParticle',
#  '이/Foreign',
#  '빨리/Adverb',
#  '존재/Noun',
#  '힘/Noun',
#  '진정하다/Adjective',
#  '바로/Noun',
#  '주제/Noun',
#  '바라다/Verb',
#  '목소리/Noun',
#  '에요/Josa',
#  '....../Punctuation',
#  '풀다/Verb',
#  '낭비/Noun',
#  '어/Suffix',
#  '잡다/Verb',
#  '망치다/Verb',
#  '돋다/Verb',
#  '화려하다/Adjective',
#  '안보/Noun',
#  '거의/Noun',
#  '죽/Noun',
#  '당신/Noun',
#  '말고/Josa',
#  '몇번/Noun',
#  '가볍다/Adjective',
#  '나라/Noun',
#  '다른/Modifier',
#  '라니/Josa',
#  '질질/Noun',
#  '엄청나다/Adjective',
#  '맞추다/Verb',
#  '줄거리/Noun',
#  '독특하다/Adjective',
#  '지나다/Verb',
#  '판타지/Noun',
#  '딸/Noun',
#  '성하다/Adjective',
#  '신/Noun',
#  '모든/Modifier',
#  '갑자기/Noun',
#  '이번/Noun',
#  '점주/Noun',
#  '아버지/Noun',
#  '좀비/Noun',
#  '담다/Verb',
#  '피/Noun',
#  '그러나/Conjunction',
#  '에선/Josa',
#  '넣다/Verb',
#  '전부/Noun',
#  '의도/Noun',
#  '뜨다/Verb',
#  '어른/Noun',
#  '상영/Noun',
#  '재/Noun',
#  '실제/Noun',
#  '흥미롭다/Adjective',
#  '각본/Noun',
#  '시청률/Noun',
#  '넘치다/Adjective',
#  '제작/Noun',
#  '만하/Noun',
#  '으로도/Josa',
#  '맛/Noun',
#  '평론가/Noun',
#  '곳/Noun',
#  '바/Noun',
#  '한편/Noun',
#  '땜/Noun',
#  '화면/Noun',
#  '영/Noun',
#  '답/Noun',
#  '필요/Noun',
#  '기다리다/Verb',
#  '그녀/Noun',
#  '극장판/Noun',
#  '//Punctuation',
#  '막/Noun',
#  '간다/Noun',
#  '10년/Number',
#  '중국/Noun',
#  '평/Noun',
#  '만들어지다/Verb',
#  '란/Noun',
#  '히/Adverb',
#  '이하/Noun',
#  '볼때/Noun',
#  '세계/Noun',
#  '세/Noun',
#  '짱/Suffix',
#  '상/Suffix',
#  '억지스럽다/Adjective',
#  '에서도/Josa',
#  '이기다/Verb',
#  '밑/Noun',
#  '가치/Noun',
#  '바꾸다/Verb',
#  '선/Noun',
#  '발/Noun',
#  '일단/Noun',
#  '관람/Noun',
#  '오글거리다/Verb',
#  '똥/Noun',
#  '스타일/Noun',
#  '선택/Noun',
#  '원/Modifier',
#  '복수/Noun',
#  '성우/Noun',
#  '뻔/Noun',
#  '요소/Noun',
#  '항상/Noun',
#  'TV/Alpha',
#  '성/Modifier',
#  '둘/Noun',
#  '어디서/Adverb',
#  '에서는/Josa',
#  '흥행/Noun',
#  '역/Noun',
#  '보내다/Verb',
#  '달다/Verb',
#  '힘드다/Adjective',
#  '너무하다/Adjective',
#  '올리다/Verb',
#  '세/Modifier',
#  '래/Josa',
#  '그때/Noun',
#  '부르다/Verb',
#  '거기/Noun',
#  '갖다/Verb',
#  '참고/Noun',
#  '더욱/Noun',
#  '확실하다/Adjective',
#  '치고/Josa',
#  '진행/Noun',
#  '첨/Adverb',
#  '가보다/Verb',
#  '구/Noun',
#  '면/Noun',
#  '불편하다/Adjective',
#  '걸리다/Verb',
#  '점점/Noun',
#  '물론/Adverb',
#  '조/Modifier',
#  '들어가다/Verb',
#  '아빠/Noun',
#  '수가/Noun',
#  '역대/Noun',
#  '평범하다/Adjective',
#  '잃다/Verb',
#  '편집/Noun',
#  '완성/Noun',
#  '전형/Noun',
#  '거지/Noun',
#  '멜로/Noun',
#  '단순하다/Adjective',
#  '어이/Noun',
#  '듣다/Verb',
#  '화이팅/Noun',
#  '허무하다/Adjective',
#  '끼다/Verb',
#  '흐르다/Verb',
#  '이냐/Josa',
#  '상미/Noun',
#  '이에요/Josa',
#  '술/Noun',
#  '짧다/Adjective',
#  '때리다/Verb',
#  '인거/Josa',
#  '과/Noun',
#  'tv/Alpha',
#  '초/Noun',
#  '불륜/Noun',
#  '에겐/Josa',
#  '동안/Noun',
#  '탄탄하다/Adjective',
#  '가지다/Verb',
#  '쯤/Suffix',
#  '드/Noun',
#  '돋보이다/Verb',
#  '걸다/Verb',
#  '개그/Noun',
#  '엉망/Noun',
#  '잠/Noun',
#  '예상/Noun',
#  '라서/Josa',
#  '사건/Noun',
#  '즐기다/Verb',
#  '미화/Noun',
#  '중반/Noun',
#  '그만/Adverb',
#  '지겹다/Adjective',
#  '꿀잼/Noun',
#  '낫다/Noun',
#  '병맛/Noun',
#  '~!!/Punctuation',
#  '그게/Noun',
#  '소중하다/Adjective',
#  '키/Noun',
#  '설명/Noun',
#  '똑같다/Adjective',
#  '몇/Noun',
#  '대로/Josa',
#  '과거/Noun',
#  '에/Foreign',
#  '프랑스/Noun',
#  '찾아보다/Verb',
#  '또한/Noun',
#  '적당하다/Adjective',
#  '비추다/Verb',
#  '중요하다/Adjective',
#  '메다/Verb',
#  '손/Noun',
#  '훈훈하다/Adjective',
#  '흥미진진/Noun',
#  '무/Noun',
#  '-_-/Punctuation',
#  '도저히/Noun',
#  '노력/Noun',
#  '원래/Noun',
#  '그냥/Modifier',
#  '댓글/Noun',
#  '그래픽/Noun',
#  '티/Noun',
#  '죽음/Noun',
#  '척/Noun',
#  '흥미/Noun',
#  '무조건/Noun',
#  '마르다/Adjective',
#  '리/Noun',
#  '취향/Noun',
#  '소/Modifier',
#  '갈다/Verb',
#  '싸우다/Verb',
#  '거리/Noun',
#  '몸/Noun',
#  '식상하다/Adjective',
#  '배/Noun',
#  '자극/Noun',
#  '뛰어나다/Adjective',
#  '화가/Noun',
#  '울/Noun',
#  'good/Alpha',
#  '난/Josa',
#  '화보/Noun',
#  '만으로도/Josa',
#  '역겹다/Adjective',
#  '감상/Noun',
#  '간/Suffix',
#  '새끼/Noun',
#  '한심하다/Adjective',
#  '관/Noun',
#  '학교/Noun',
#  '헐다/Verb',
#  '고/Noun',
#  'ost/Alpha',
#  '괜히/Adverb',
#  '씩/Suffix',
#  '자꾸/Noun',
#  '닿다/Verb',
#  '길다/Adjective',
#  '뭐라다/Verb',
#  '아저씨/Noun']

# %%
def term_frequency(doc):
    return [doc.count(word) for word in selected_words] 

train_x = [term_frequency(d) for d, _ in train_docs]
test_x = [term_frequency(d) for d, _ in test_docs]
train_y = [c for _, c in train_docs]
test_y = [c for _, c in test_docs]

x_train = np.asarray(train_x).astype('float32')
x_test = np.asarray(test_x).astype('float32')
y_train = np.asarray(train_y).astype('float32')
y_test = np.asarray(test_y).astype('float32')

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras import losses
from keras import metrics
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=optimizers.RMSprop(lr=0.001), loss=losses.binary_crossentropy, metrics=[metrics.binary_accuracy])

model.fit(x_train, y_train, epochs=10, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# WARNING:tensorflow:From c:\users\2qqns\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From c:\users\2qqns\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 150000/150000 [==============================] - 5s 36us/step - loss: 0.4320 - binary_accuracy: 0.8018
# Epoch 2/10
# 150000/150000 [==============================] - 5s 34us/step - loss: 0.3811 - binary_accuracy: 0.8241: 1s - loss: 0.3838 - binary_accuracy: 0.822 - ETA: 1s - loss: 0.3836 - bi - ETA: 0s - loss: 0.3810 - binary_accuracy: 0
# Epoch 3/10
# 150000/150000 [==============================] - 4s 27us/step - loss: 0.3651 - binary_accuracy: 0.8332
# Epoch 4/10
# 150000/150000 [==============================] - 4s 24us/step - loss: 0.3519 - binary_accuracy: 0.8411:
# Epoch 5/10
# 150000/150000 [==============================] - 3s 23us/step - loss: 0.3394 - binary_accuracy: 0.8487
# Epoch 6/10
# 150000/150000 [==============================] - 3s 22us/step - loss: 0.3276 - binary_accuracy: 0.8548
# Epoch 7/10
# 150000/150000 [==============================] - 3s 21us/step - loss: 0.3156 - binary_accuracy: 0.8616
# Epoch 8/10
# 150000/150000 [==============================] - 3s 21us/step - loss: 0.3038 - binary_accuracy: 0.8679
# Epoch 9/10
# 150000/150000 [==============================] - 3s 21us/step - loss: 0.2919 - binary_accuracy: 0.8735
# Epoch 10/10
# 150000/150000 [==============================] - 3s 23us/step - loss: 0.2807 - binary_accuracy: 0.8786
# 50000/50000 [==============================] - 2s 39us/step

# %%
def predict_pos_neg(review):
    token = tokenize(review)
    tf = term_frequency(token)
    data = np.expand_dims(np.asarray(tf).astype('float32'), axis=0)
    score = float(model.predict(data))
    if(score > 0.5):
        print("[{}]는 {:.2f}% 긍정\n".format(review, score * 100))
    else:
        print("[{}]는 {:.2f}% 부정\n".format(review, (1 - score) * 100))


# 테스트
predict_pos_neg("할줄아는거 없고 해낼 자신도 없는데 한심하고 착잡하다")
predict_pos_neg("슬픈 영화 보고 그냥 펑펑 울고 싶은데 추천 좀 해주세요")
predict_pos_neg("겨드랑이에서 삼겹살 냄새 나는듯")
predict_pos_neg("진짜 너무 심심한데 놀아줄사람")
predict_pos_neg("튜터링 돈 언제 주냐 ㅋㅋㅋㅋㅋ")
predict_pos_neg("노트북 브랜드 추천점")
predict_pos_neg("문제다 문제 우리나라 정치나 학교 총학이나 나 자신이나 전부 문제야....")
# Out:
# [할줄아는거 없고 해낼 자신도 없는데 한심하고 착잡하다]는 95.76% 부정
#
# [슬픈 영화 보고 그냥 펑펑 울고 싶은데 추천 좀 해주세요]는 97.36% 긍정
#
# [겨드랑이에서 삼겹살 냄새 나는듯]는 56.33% 긍정
#
# [진짜 너무 심심한데 놀아줄사람]는 78.00% 부정
#
# [튜터링 돈 언제 주냐 ㅋㅋㅋㅋㅋ]는 89.45% 부정
#
# [노트북 브랜드 추천점]는 59.35% 긍정
#
# [문제다 문제 우리나라 정치나 학교 총학이나 나 자신이나 전부 문제야....]는 88.27% 부정
