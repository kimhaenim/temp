# %%
import urllib.request
import time
#import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from konlpy.tag import Okt

#크롬 연결
driver = webdriver.Chrome('C:\chromedriver')
driver.implicitly_wait(3)
#계당교양교육원 교양
driver.get('https://www.smu.ac.kr/smgs/intro/professor.do?mode=list&&pagerLimit=50&pager.offset=0')
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

#교양 교수님들 정보만 담을 리스트
nm_name_list = [] #교수명
nm_major_list = [] #계당교양교육원 교양 교수님들은 교양으로 모두 insert하고, 학과는 학과명으로 insert.
nm_info_list = [] #교수정보
nm_picture_list = [] #사진

# %%
name = soup.select('#item_body > div.sub-container > div.content-wrap > div.prof-wrap.con-box > div > div > div:nth-child(2) > div > ul > li > div.texts > strong')
info = soup.select('#item_body > div.sub-container > div.content-wrap > div.prof-wrap.con-box > div > div > div:nth-child(2) > div > ul > li > div.texts > ul')
for n in name:
    nm_name_list.append(n.text.strip())
    #사이트에서뽑아온 교수님 이름만큼 '교양'이라고 삽입
    nm_major_list.append('교양') 
for n in info:
    nm_info_list.append(n.text.strip())

# %%
# 사진 가져오기
front_url = "https://www.smu.ac.kr"
ul_tag = soup.find('ul', {'class', 'board-thumb-wrap2 col2'})

picture = ul_tag.find_all('img', {'class', 'pImg'})
for images in picture:
    nm_picture_list.append(front_url + images.get('src'))

# %%
import re
import pandas as pd

intro = pd.DataFrame()
intro['학과/교양']= nm_major_list
intro['교수명']=nm_name_list
intro['교수정보']=nm_info_list
intro.head(40)
# Out:
#         교수명                                               교수정보
# 0   프란시스브래넌  학위 : 석사\n세부전공 : Education Policy\n연구실 : (A관)사범...
# 1       홍세령  학위 : 박사\n세부전공 : 물리화학전공\n연구실 : (K관)자연과학대학관 (K31...
# 2       전영옥  학위 : 박사\n세부전공 : 국어학전공\n연구실 : (A관)사범대학관 (A211)\...
# 3       김인주  학위 : 석사\n세부전공 : 일본어학\n연구실 : (M관)월해관 (M328)\n연락...
# 4       심예지  학위 : 박사\n세부전공 : 수사학/글쓰기(영어교육)\n연구실 : (O관)제1교수회...
# 5       이연숙  학위 : 박사\n세부전공 : 영어교육\n연구실 : (A관)사범대학관 (A214)\n...
# 6       이재학  학위 : 박사\n세부전공 : e-비지니스\n연구실 : (A관)사범대학관 (A313)...
# 7       김일림  학위 : 박사\n세부전공 : 문화 역사지리\n연구실 : (B관)미술관 (B211)\...
# 8       이형국  학위 : 박사\n세부전공 : 교육심리및상담심리전공\n연구실 : (S관)중앙교수회관 ...
# 9       정희정  학위 : 박사\n세부전공 : Language Testing\n연구실 : (N관)인문...
# 10      권정인  학위 : 박사\n세부전공 : 컴퓨터교육\n연구실 : (A관)사범대학관 (A216)\...
# 11      오경은                    학위 : 박사\n연구실 : (A관)사범대학관 (A212)

# %%
#학과 교수님들 정보만 담을 리스트
name_list = [] #교수명
major_list = [] #교수님이 속한 학과명으로 insert.
info_list = [] #교수정보
picture_list = [] #사진

# %%
###총 31개 학과
major_count=1
while(True):
    if major_count == 30:  #총 31개 학과이나, 
        #국가안보학과와 융합경영학과는 웹페이지의 구조가 다르므로 따로 추출.
        #29개 학과만 정보추출하고, 30이 되면 빠져나온다.
        break
    #과마다 교수님 수가 20명이 넘어가면, 2페이지로 넘어가기때문에
    #교수소개 한 페이지안에 최대 50명의 교수님을 다 보여주도록 주소설정.
    #소속교수님이 최대 50명을 넘는 학과는 없다. 소속교수님이 가장 많은 학과 최대21명.
#컴퓨터과학과 교수진
    if major_count==1 :
        driver.get('https://www.smu.ac.kr/cs/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#전기공학과 교수진
    if major_count==2 :
        driver.get('https://www.smu.ac.kr/electric/faculty/faculty.do?https://www.smu.ac.kr/cs/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#융합전자공학과 교수진
    if major_count==3 :
        driver.get('https://www.smu.ac.kr/electronic/faculty/faculty.do?https://www.smu.ac.kr/cs/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#휴먼지능정보공학과 교수진
    if major_count==4 :
        driver.get('https://www.smu.ac.kr/hi/faculty/faculty.do?https://www.smu.ac.kr/cs/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#경제금융학부 교수진
    if major_count==5 :
        driver.get('https://www.smu.ac.kr/economic/faculty/faculty.do?https://www.smu.ac.kr/cs/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#경영학부 교수진
    if major_count==6 :
        driver.get('https://www.smu.ac.kr/smubiz/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#글로벌경영학과 교수진
    if major_count==7 :
        driver.get('https://www.smu.ac.kr/newmajoritb/intro/faculty.do?https://www.smu.ac.kr/cs/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#생활예술학과 교수진
    if major_count==8 :
        driver.get('https://www.smu.ac.kr/smulad/faculity/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#국어교육과 교수진
    if major_count==9 :
        driver.get('https://www.smu.ac.kr/koredu/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#영어교육과 교수진
    if major_count==10 :
        driver.get('https://www.smu.ac.kr/engedu/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#교육학과 교수진
    if major_count==11 :
        driver.get('https://www.smu.ac.kr/peda/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#수학교육과 교수진
    if major_count==12 :
        driver.get('https://www.smu.ac.kr/mathedu/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#지적재산권학과 교수진
    if major_count==13 :
        driver.get('https://www.smu.ac.kr/cc/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#한일문화콘텐츠학과 교수진
    if major_count==14 :
        driver.get('https://www.smu.ac.kr/kjc/intro/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#역사콘텐츠학과 교수진
    if major_count==15 :
        driver.get('https://www.smu.ac.kr/history/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#문헌정보학과 교수진
    if major_count==16 :
        driver.get('https://www.smu.ac.kr/libinfo/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#공공인재학부 교수진
    if major_count==17 :
        driver.get('https://www.smu.ac.kr/public/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#음악학부 교수진
    if major_count==18 :
        driver.get('https://www.smu.ac.kr/music/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#공간환경학부 교수진
    if major_count==19 :
        driver.get('https://www.smu.ac.kr/space/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#가족복지학과 교수진
    if major_count==20 :
        driver.get('https://www.smu.ac.kr/smfamily/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#화학에너지공학과 교수진
    if major_count==21 :
        driver.get('https://www.smu.ac.kr/cee/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#생명공학과 교수진
    if major_count==22 :
        driver.get('https://www.smu.ac.kr/biotechnology/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#화공신소재학과 교수진
    if major_count==23 :
        driver.get('https://www.smu.ac.kr/ichemistry/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#게임학과 교수진
    if major_count==24 :
        driver.get('https://www.smu.ac.kr/game01/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#식품영양학과 교수진
    if major_count==25 :
        driver.get('https://www.smu.ac.kr/foodnutrition/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#의류학과 교수진
    if major_count==26 :
        driver.get('https://www.smu.ac.kr/clothing2/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#스포츠건강관리학과 교수진
    if major_count==27 :
        driver.get('https://www.smu.ac.kr/smpe/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#무용예술학과 교수진
    if major_count==28 :
        driver.get('https://www.smu.ac.kr/dance/intro/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#조형예술학과 교수진
    if major_count==29 :
        driver.get('https://www.smu.ac.kr/finearts/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')


    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    
    name = soup.select('#jwxe_main_content > div > div > div:nth-child(2) > div > ul > li > div.texts > strong')
    for n in name:
        name_list.append(n.text.strip())
        if major_count ==1 :
            major_list.append('컴퓨터과학과')
        if major_count ==2 :
            major_list.append('전기공학과')
        if major_count ==3 :
            major_list.append('융합전자공학과')
        if major_count ==4 :
            major_list.append('휴먼지능정보공학과')
        if major_count ==5 :
            major_list.append('경제금융학부')
        if major_count ==6 :
            major_list.append('경영학부')
        if major_count ==7 :
            major_list.append('글로벌경영학과')
        if major_count ==8 :
            major_list.append('생활예술학과')
        if major_count ==9 :
            major_list.append('국어교육과')
        if major_count ==10 :
            major_list.append('영어교육과')
        if major_count ==11 :
            major_list.append('교육학과')
        if major_count ==12 :
            major_list.append('수학교육과')
        if major_count ==13 :
            major_list.append('지적재산권학과')
        if major_count ==14 :
            major_list.append('한일문화콘텐츠학과')
        if major_count ==15 :
            major_list.append('역사콘텐츠학과')
        if major_count ==16 :
            major_list.append('문헌정보학과')
        if major_count ==17 :
            major_list.append('공공인재학부')
        if major_count ==18 :
            major_list.append('음악학부')
        if major_count ==19 :
            major_list.append('공간환경학부')
        if major_count ==20 :
            major_list.append('가족복지학과')
        if major_count ==21 :
            major_list.append('화학에너지공학과')
        if major_count ==22 :
            major_list.append('생명공학과')
        if major_count ==23 :
            major_list.append('화공신소재학과')
        if major_count ==24 :
            major_list.append('게임학과')
        if major_count ==25 :
            major_list.append('식품영양학과')
        if major_count ==26 :
            major_list.append('의류학과')
        if major_count ==27 :
            major_list.append('스포츠건강관리학과')
        if major_count ==28 :
            major_list.append('무용예술학과')
        if major_count ==29 :
            major_list.append('조형예술학과')

    #정보 가져오기
    info = soup.select('#jwxe_main_content > div > div > div:nth-child(2) > div > ul > li > div.texts > ul')
    for n in info:
        info_list.append(n.text.strip())
    
    # 사진 가져오기
    front_url = "https://www.smu.ac.kr" 
    ul_tag = soup.find('ul', {'class', 'board-thumb-wrap2 col2'})
    picture = ul_tag.find_all('img', {'class', 'pImg'})
    for images in picture:
        picture_list.append(front_url + images.get('src'))

    major_count+= 1

# %%
#남은 두 학과(국가안보학과, 융합경영학과)도 추출 
major_count=1

while(True):
    if major_count == 3: 
        #국가안보학과와 융합경영학과는 웹페이지의 구조가 다르므로 따로 추출.
        #두 학과만 정보추출하고, 3이 되면 빠져나온다.
        break
#국가안보학과 교수진
    if major_count==1 :
        driver.get('https://www.smu.ac.kr/sdms/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
#융합경영학과 교수진
    if major_count==2 :
        driver.get('https://www.smu.ac.kr/cm/faculty/faculty.do?mode=list&&pagerLimit=50&pager.offset=0')
        
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
  
    name = soup.select('#ko > div.common-board > div > ul > li > div.texts > strong')
    for n in name:
        name_list.append(n.text.strip())
        if major_count ==1 :
            major_list.append('국가안보학과')
        if major_count ==2 :
            major_list.append('융합경영학과')
    
    info = soup.select('#ko > div.common-board > div > ul > li > div.texts > ul')
    for n in info:
        info_list.append(n.text.strip())
        
    # 사진 가져오기
    front_url = "https://www.smu.ac.kr" 
    ul_tag = soup.find('ul', {'class', 'board-thumb-wrap2 col2'})
    picture = ul_tag.find_all('img', {'class', 'pImg'})
    for images in picture:
        picture_list.append(front_url + images.get('src'))

    major_count+= 1

# %%
print(len(name_list))
print(len(major_list))
print(len(info_list))
print(len(picture_list))
# Out:
# 227
# 227
# 227
# 227

# %%
#에브리타임 로그인 페이지
driver.get('https://everytime.kr/login')
driver.find_element_by_name('userid').send_keys('aosladl')
driver.find_element_by_name('password').send_keys('hn2168028')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').click()

# %%
#모든 학과명 = all_major
all_major = list()
for n in major_list:
    if not n in all_major :
        all_major.append(n)
        
#학과별 게시글 관련 정보를 담을 리스트
majorboard_like_list = list()
majorboard_title_list = list()
majorboard_content_list = list()
majorboard_major_list = list()
majorboard_date_list = list()

# %%
major_page = list() #학과마다 총 페이지를 담을 리스트
for major in all_major:
    page_count = 1
    while(True):
        driver.get(url+major+p+str(page_count))
        try:
            test1 = driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a')
            test2 = driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next')
            page_count+=1
        except Exception as e:
            major_page.append(page_count)
            break

# %%
print(len(major_page))
print(major_page)
# Out:
# 31
# [8, 4, 3, 3, 5, 8, 6, 5, 5, 6, 8, 3, 4, 4, 4, 4, 6, 5, 5, 8, 3, 6, 3, 7, 3, 11, 3, 2, 5, 3, 2]

# %%
#전체게시글 조회 페이지
url = 'https://everytime.kr/search/all/'
p = '/p/'
major_page_index = 0
for major in all_major:
    page_count = 1
    while(True) :
        print('현재 '+major+'의 '+str(page_count)+'페이지입니다.')
        if page_count == major_page[major_page_index]:
            print(major+'의 마지막 페이지네요. 글이 없습니다. 다음 학과로 넘어갑니다.')
            major_page_index+=1
            break
        driver.get(url+major+p+str(page_count))
        driver.implicitly_wait(3)
        time.sleep(2)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser') 
        print('크롤링 중...')
        everytime_link = list()
        content = list()
        content = soup.findAll('article') #해당 페이지의 게시물들
        for u in content: #페이지의 게시글 url을 가져온다.
            find_url = u.find('a', attrs={'class', 'article'}).get('href') #url 가져오기
            everytime_link.append(find_url) #url 저장
        for l in everytime_link: #가져온 url
            try:
                driver.get('https://everytime.kr'+l)
                time.sleep(3)
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')           
                try:
                    title = soup.find('h2', attrs={'class', 'large'}).get_text()     
                except Exception as e:
                    title = 'null'
                contents = soup.find('p', attrs={'class', 'large'})
                date = soup.find('time', attrs={'class', 'large'})
                like = soup.find('li', attrs={'class','vote'})  
                majorboard_major_list.append(major)
                majorboard_title_list.append(title)
                majorboard_content_list.append(contents.get_text())
                majorboard_like_list.append(like.text.strip())
                majorboard_date_list.append(date.get_text()) 
            except Exception as e:
                continue  
        print(major+' '+str(page_count)+'페이지의 게시글 개수')
        print(len(majorboard_major_list)) 
        print(len(majorboard_title_list))
        print(len(majorboard_content_list))
        print(len(majorboard_date_list)) #date
        print(len(majorboard_like_list))#like
        page_count+=1
# Out:
# 현재컴퓨터과학과의 1페이지임
# 크롤링중
# 컴퓨터과학과의1페이지의 개수
# 24
# 24
# 24
# 24
# 24
# 현재컴퓨터과학과의 2페이지임
# 크롤링중
# 컴퓨터과학과의2페이지의 개수
# 40
# 40
# 40
# 40
# 40
# 현재컴퓨터과학과의 3페이지임
# 크롤링중
# 컴퓨터과학과의3페이지의 개수
# 51
# 51
# 51
# 51
# 51
# 현재컴퓨터과학과의 4페이지임
# 크롤링중
# 컴퓨터과학과의4페이지의 개수
# 67
# 67
# 67
# 67
# 67
# 현재컴퓨터과학과의 5페이지임
# 크롤링중
# 컴퓨터과학과의5페이지의 개수
# 87
# 87
# 87
# 87
# 87
# 현재컴퓨터과학과의 6페이지임
# 크롤링중
# 컴퓨터과학과의6페이지의 개수
# 107
# 107
# 107
# 107
# 107
# 현재컴퓨터과학과의 7페이지임
# 크롤링중
# 컴퓨터과학과의7페이지의 개수
# 113
# 113
# 113
# 113
# 113
# 현재컴퓨터과학과의 8페이지임
# 컴퓨터과학과의 페이지 끝. 다음 학과로 넘어감!
# 현재전기공학과의 1페이지임
# 크롤링중
# 전기공학과의1페이지의 개수
# 123
# 123
# 123
# 123
# 123
# 현재전기공학과의 2페이지임
# 크롤링중
# 전기공학과의2페이지의 개수
# 136
# 136
# 136
# 136
# 136
# 현재전기공학과의 3페이지임
# 크롤링중
# 전기공학과의3페이지의 개수
# 154
# 154
# 154
# 154
# 154
# 현재전기공학과의 4페이지임
# 전기공학과의 페이지 끝. 다음 학과로 넘어감!
# 현재융합전자공학과의 1페이지임
# 크롤링중
# 융합전자공학과의1페이지의 개수
# 162
# 162
# 162
# 162
# 162
# 현재융합전자공학과의 2페이지임
# 크롤링중
# 융합전자공학과의2페이지의 개수
# 164
# 164
# 164
# 164
# 164
# 현재융합전자공학과의 3페이지임
# 융합전자공학과의 페이지 끝. 다음 학과로 넘어감!
# 현재휴먼지능정보공학과의 1페이지임
# 크롤링중
# 휴먼지능정보공학과의1페이지의 개수
# 173
# 173
# 173
# 173
# 173
# 현재휴먼지능정보공학과의 2페이지임
# 크롤링중
# 휴먼지능정보공학과의2페이지의 개수
# 182
# 182
# 182
# 182
# 182
# 현재휴먼지능정보공학과의 3페이지임
# 휴먼지능정보공학과의 페이지 끝. 다음 학과로 넘어감!
# 현재경제금융학부의 1페이지임
# 크롤링중
# 경제금융학부의1페이지의 개수
# 191
# 191
# 191
# 191
# 191
# 현재경제금융학부의 2페이지임
# 크롤링중
# 경제금융학부의2페이지의 개수
# 202
# 202
# 202
# 202
# 202
# 현재경제금융학부의 3페이지임
# 크롤링중
# 경제금융학부의3페이지의 개수
# 220
# 220
# 220
# 220
# 220
# 현재경제금융학부의 4페이지임
# 크롤링중
# 경제금융학부의4페이지의 개수
# 224
# 224
# 224
# 224
# 224
# 현재경제금융학부의 5페이지임
# 경제금융학부의 페이지 끝. 다음 학과로 넘어감!
# 현재경영학부의 1페이지임
# 크롤링중
# 경영학부의1페이지의 개수
# 233
# 233
# 233
# 233
# 233
# 현재경영학부의 2페이지임
# 크롤링중
# 경영학부의2페이지의 개수
# 245
# 245
# 245
# 245
# 245
# 현재경영학부의 3페이지임
# 크롤링중
# 경영학부의3페이지의 개수
# 256
# 256
# 256
# 256
# 256
# 현재경영학부의 4페이지임
# 크롤링중
# 경영학부의4페이지의 개수
# 270
# 270
# 270
# 270
# 270
# 현재경영학부의 5페이지임
# 크롤링중
# 경영학부의5페이지의 개수
# 289
# 289
# 289
# 289
# 289
# 현재경영학부의 6페이지임
# 크롤링중
# 경영학부의6페이지의 개수
# 309
# 309
# 309
# 309
# 309
# 현재경영학부의 7페이지임
# 크롤링중
# 경영학부의7페이지의 개수
# 328
# 328
# 328
# 328
# 328
# 현재경영학부의 8페이지임
# 경영학부의 페이지 끝. 다음 학과로 넘어감!
# 현재글로벌경영학과의 1페이지임
# 크롤링중
# 글로벌경영학과의1페이지의 개수
# 341
# 341
# 341
# 341
# 341
# 현재글로벌경영학과의 2페이지임
# 크롤링중
# 글로벌경영학과의2페이지의 개수
# 357
# 357
# 357
# 357
# 357
# 현재글로벌경영학과의 3페이지임
# 크롤링중
# 글로벌경영학과의3페이지의 개수
# 375
# 375
# 375
# 375
# 375
# 현재글로벌경영학과의 4페이지임
# 크롤링중
# 글로벌경영학과의4페이지의 개수
# 394
# 394
# 394
# 394
# 394
# 현재글로벌경영학과의 5페이지임
# 크롤링중
# 글로벌경영학과의5페이지의 개수
# 405
# 405
# 405
# 405
# 405
# 현재글로벌경영학과의 6페이지임
# 글로벌경영학과의 페이지 끝. 다음 학과로 넘어감!
# 현재생활예술학과의 1페이지임
# 크롤링중
# 생활예술학과의1페이지의 개수
# 410
# 410
# 410
# 410
# 410
# 현재생활예술학과의 2페이지임
# 크롤링중
# 생활예술학과의2페이지의 개수
# 420
# 420
# 420
# 420
# 420
# 현재생활예술학과의 3페이지임
# 크롤링중
# 생활예술학과의3페이지의 개수
# 438
# 438
# 438
# 438
# 438
# 현재생활예술학과의 4페이지임
# 크롤링중
# 생활예술학과의4페이지의 개수
# 440
# 440
# 440
# 440
# 440
# 현재생활예술학과의 5페이지임
# 생활예술학과의 페이지 끝. 다음 학과로 넘어감!
# 현재국어교육과의 1페이지임
# 크롤링중
# 국어교육과의1페이지의 개수
# 455
# 455
# 455
# 455
# 455
# 현재국어교육과의 2페이지임
# 크롤링중
# 국어교육과의2페이지의 개수
# 468
# 468
# 468
# 468
# 468
# 현재국어교육과의 3페이지임
# 크롤링중
# 국어교육과의3페이지의 개수
# 488
# 488
# 488
# 488
# 488
# 현재국어교육과의 4페이지임
# 크롤링중
# 국어교육과의4페이지의 개수
# 497
# 497
# 497
# 497
# 497
# 현재국어교육과의 5페이지임
# 국어교육과의 페이지 끝. 다음 학과로 넘어감!
# 현재영어교육과의 1페이지임
# 크롤링중
# 영어교육과의1페이지의 개수
# 505
# 505
# 505
# 505
# 505
# 현재영어교육과의 2페이지임
# 크롤링중
# 영어교육과의2페이지의 개수
# 510
# 510
# 510
# 510
# 510
# 현재영어교육과의 3페이지임
# 크롤링중
# 영어교육과의3페이지의 개수
# 530
# 530
# 530
# 530
# 530
# 현재영어교육과의 4페이지임
# 크롤링중
# 영어교육과의4페이지의 개수
# 550
# 550
# 550
# 550
# 550
# 현재영어교육과의 5페이지임
# 크롤링중
# 영어교육과의5페이지의 개수
# 561
# 561
# 561
# 561
# 561
# 현재영어교육과의 6페이지임
# 영어교육과의 페이지 끝. 다음 학과로 넘어감!
# 현재교육학과의 1페이지임
# 크롤링중
# 교육학과의1페이지의 개수
# 573
# 573
# 573
# 573
# 573
# 현재교육학과의 2페이지임
# 크롤링중
# 교육학과의2페이지의 개수
# 584
# 584
# 584
# 584
# 584
# 현재교육학과의 3페이지임
# 크롤링중
# 교육학과의3페이지의 개수
# 594
# 594
# 594
# 594
# 594
# 현재교육학과의 4페이지임
# 크롤링중
# 교육학과의4페이지의 개수
# 613
# 613
# 613
# 613
# 613
# 현재교육학과의 5페이지임
# 크롤링중
# 교육학과의5페이지의 개수
# 632
# 632
# 632
# 632
# 632
# 현재교육학과의 6페이지임
# 크롤링중
# 교육학과의6페이지의 개수
# 652
# 652
# 652
# 652
# 652
# 현재교육학과의 7페이지임
# 크롤링중
# 교육학과의7페이지의 개수
# 660
# 660
# 660
# 660
# 660
# 현재교육학과의 8페이지임
# 교육학과의 페이지 끝. 다음 학과로 넘어감!
# 현재수학교육과의 1페이지임
# 크롤링중
# 수학교육과의1페이지의 개수
# 676
# 676
# 676
# 676
# 676
# 현재수학교육과의 2페이지임
# 크롤링중
# 수학교육과의2페이지의 개수
# 688
# 688
# 688
# 688
# 688
# 현재수학교육과의 3페이지임
# 수학교육과의 페이지 끝. 다음 학과로 넘어감!
# 현재지적재산권학과의 1페이지임
# 크롤링중
# 지적재산권학과의1페이지의 개수
# 700
# 700
# 700
# 700
# 700
# 현재지적재산권학과의 2페이지임
# 크롤링중
# 지적재산권학과의2페이지의 개수
# 717
# 717
# 717
# 717
# 717
# 현재지적재산권학과의 3페이지임
# 크롤링중
# 지적재산권학과의3페이지의 개수
# 721
# 721
# 721
# 721
# 721
# 현재지적재산권학과의 4페이지임
# 지적재산권학과의 페이지 끝. 다음 학과로 넘어감!
# 현재한일문화콘텐츠학과의 1페이지임
# 크롤링중
# 한일문화콘텐츠학과의1페이지의 개수
# 736
# 736
# 736
# 736
# 736
# 현재한일문화콘텐츠학과의 2페이지임
# 크롤링중
# 한일문화콘텐츠학과의2페이지의 개수
# 751
# 751
# 751
# 751
# 751
# 현재한일문화콘텐츠학과의 3페이지임
# 크롤링중
# 한일문화콘텐츠학과의3페이지의 개수
# 755
# 755
# 755
# 755
# 755
# 현재한일문화콘텐츠학과의 4페이지임
# 한일문화콘텐츠학과의 페이지 끝. 다음 학과로 넘어감!
# 현재역사콘텐츠학과의 1페이지임
# 크롤링중
# 역사콘텐츠학과의1페이지의 개수
# 763
# 763
# 763
# 763
# 763
# 현재역사콘텐츠학과의 2페이지임
# 크롤링중
# 역사콘텐츠학과의2페이지의 개수
# 783
# 783
# 783
# 783
# 783
# 현재역사콘텐츠학과의 3페이지임
# 크롤링중
# 역사콘텐츠학과의3페이지의 개수
# 785
# 785
# 785
# 785
# 785
# 현재역사콘텐츠학과의 4페이지임
# 역사콘텐츠학과의 페이지 끝. 다음 학과로 넘어감!
# 현재문헌정보학과의 1페이지임
# 크롤링중
# 문헌정보학과의1페이지의 개수
# 798
# 798
# 798
# 798
# 798
# 현재문헌정보학과의 2페이지임
# 크롤링중
# 문헌정보학과의2페이지의 개수
# 816
# 816
# 816
# 816
# 816
# 현재문헌정보학과의 3페이지임
# 크롤링중
# 문헌정보학과의3페이지의 개수
# 819
# 819
# 819
# 819
# 819
# 현재문헌정보학과의 4페이지임
# 문헌정보학과의 페이지 끝. 다음 학과로 넘어감!
# 현재공공인재학부의 1페이지임
# 크롤링중
# 공공인재학부의1페이지의 개수
# 831
# 831
# 831
# 831
# 831
# 현재공공인재학부의 2페이지임
# 크롤링중
# 공공인재학부의2페이지의 개수
# 842
# 842
# 842
# 842
# 842
# 현재공공인재학부의 3페이지임
# 크롤링중
# 공공인재학부의3페이지의 개수
# 849
# 849
# 849
# 849
# 849
# 현재공공인재학부의 4페이지임
# 크롤링중
# 공공인재학부의4페이지의 개수
# 865
# 865
# 865
# 865
# 865
# 현재공공인재학부의 5페이지임
# 크롤링중
# 공공인재학부의5페이지의 개수
# 875
# 875
# 875
# 875
# 875
# 현재공공인재학부의 6페이지임
# 공공인재학부의 페이지 끝. 다음 학과로 넘어감!
# 현재음악학부의 1페이지임
# 크롤링중
# 음악학부의1페이지의 개수
# 886
# 886
# 886
# 886
# 886
# 현재음악학부의 2페이지임
# 크롤링중
# 음악학부의2페이지의 개수
# 896
# 896
# 896
# 896
# 896
# 현재음악학부의 3페이지임
# 크롤링중
# 음악학부의3페이지의 개수
# 909
# 909
# 909
# 909
# 909
# 현재음악학부의 4페이지임
# 크롤링중
# 음악학부의4페이지의 개수
# 918
# 918
# 918
# 918
# 918
# 현재음악학부의 5페이지임
# 음악학부의 페이지 끝. 다음 학과로 넘어감!
# 현재공간환경학부의 1페이지임
# 크롤링중
# 공간환경학부의1페이지의 개수
# 927
# 927
# 927
# 927
# 927
# 현재공간환경학부의 2페이지임
# 크롤링중
# 공간환경학부의2페이지의 개수
# 936
# 936
# 936
# 936
# 936
# 현재공간환경학부의 3페이지임
# 크롤링중
# 공간환경학부의3페이지의 개수
# 946
# 946
# 946
# 946
# 946
# 현재공간환경학부의 4페이지임
# 크롤링중
# 공간환경학부의4페이지의 개수
# 962
# 962
# 962
# 962
# 962
# 현재공간환경학부의 5페이지임
# 공간환경학부의 페이지 끝. 다음 학과로 넘어감!
# 현재가족복지학과의 1페이지임
# 크롤링중
# 가족복지학과의1페이지의 개수
# 974
# 974
# 974
# 974
# 974
# 현재가족복지학과의 2페이지임
# 크롤링중
# 가족복지학과의2페이지의 개수
# 979
# 979
# 979
# 979
# 979
# 현재가족복지학과의 3페이지임
# 크롤링중
# 가족복지학과의3페이지의 개수
# 992
# 992
# 992
# 992
# 992
# 현재가족복지학과의 4페이지임
# 크롤링중
# 가족복지학과의4페이지의 개수
# 1008
# 1008
# 1008
# 1008
# 1008
# 현재가족복지학과의 5페이지임
# 크롤링중
# 가족복지학과의5페이지의 개수
# 1028
# 1028
# 1028
# 1028
# 1028
# 현재가족복지학과의 6페이지임
# 크롤링중
# 가족복지학과의6페이지의 개수
# 1048
# 1048
# 1048
# 1048
# 1048
# 현재가족복지학과의 7페이지임
# 크롤링중
# 가족복지학과의7페이지의 개수
# 1049
# 1049
# 1049
# 1049
# 1049
# 현재가족복지학과의 8페이지임
# 가족복지학과의 페이지 끝. 다음 학과로 넘어감!
# 현재화학에너지공학과의 1페이지임
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-34-3a91366378dd> in <module>
#      14         driver.implicitly_wait(3)
#      15         time.sleep(2)
# ---> 16         html = driver.page_source
#      17         soup = BeautifulSoup(html, 'html.parser')
#      18         print('크롤링중')
#
# c:\users\2qqns\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# c:\users\2qqns\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# c:\users\2qqns\appdata\local\programs\python\python36-32\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=74.0.3729.131)
#   (Driver info: chromedriver=2.46.628402 (536cd7adbad73a3783fdc2cab92ab2ba7ec361e1),platform=Windows NT 10.0.17134 x86_64)

# %%
m = pd.DataFrame()
m['학과/교양']= majorboard_major_list
m['타이틀']=majorboard_title_list
m['내용']=majorboard_content_list
m['날짜']=majorboard_date_list
m['좋아요수']=majorboard_like_list
m.head(50)
# Out:
#      학과/교양                                   타이틀  \
# 0   컴퓨터과학과                         상명대 출신 교직원 정리
# 1   컴퓨터과학과                    컴퓨터과학과 사물함 도둑이 있네요
# 2   컴퓨터과학과          [스캐치][공지] 대학평의원회 회의 총학생회 입장문
# 3   컴퓨터과학과                       사물함 자물쇠 어떻게 따나요
# 4   컴퓨터과학과                              컴과 튜티 모집
# 5   컴퓨터과학과                                  null
# 6   컴퓨터과학과             [스캐치][공지] 제1회 축제공모전 선발 결과
# 7   컴퓨터과학과                🤗SMUSC 알고리즘 소모임 홍보글~!🤗
# 8   컴퓨터과학과  ⚠️모집날짜변경⚠️ 학술동아리 🐳이니로🐳에서 신입부원을 모집합니다
# 9   컴퓨터과학과                                  null
# 10  컴퓨터과학과                                  null
# 11  컴퓨터과학과                                  null
# 12  컴퓨터과학과                         상명대 출신 교직원 정리
# 13  컴퓨터과학과                    컴퓨터과학과 사물함 도둑이 있네요
# 14  컴퓨터과학과          [스캐치][공지] 대학평의원회 회의 총학생회 입장문
# 15  컴퓨터과학과                       사물함 자물쇠 어떻게 따나요
# 16  컴퓨터과학과                              컴과 튜티 모집
# 17  컴퓨터과학과                                  null
# 18  컴퓨터과학과             [스캐치][공지] 제1회 축제공모전 선발 결과
# 19  컴퓨터과학과                🤗SMUSC 알고리즘 소모임 홍보글~!🤗
# 20  컴퓨터과학과  ⚠️모집날짜변경⚠️ 학술동아리 🐳이니로🐳에서 신입부원을 모집합니다
# 21  컴퓨터과학과                                  null
# 22  컴퓨터과학과                                  null
# 23  컴퓨터과학과                                  null
# 24  컴퓨터과학과                                  null
# 25  컴퓨터과학과                                  null
# 26  컴퓨터과학과                                  null
# 27  컴퓨터과학과                                  null
# 28  컴퓨터과학과                                  null
# 29  컴퓨터과학과                                  null
# 30  컴퓨터과학과                                  null
# 31  컴퓨터과학과                                  null
# 32  컴퓨터과학과                                  null
# 33  컴퓨터과학과                        컴퓨터과학과 과단톡있나요?
# 34  컴퓨터과학과                                  null
# 35  컴퓨터과학과                                  null
# 36  컴퓨터과학과                         컴퓨터과학과 면학떴나요?
# 37  컴퓨터과학과                        컴퓨터과학과 수강인원 증원
# 38  컴퓨터과학과                                  null
# 39  컴퓨터과학과                                  null
# 40  컴퓨터과학과                                  null
# 41  컴퓨터과학과                 빅데이터과학연계전공 다른과는 못하나요?
# 42  컴퓨터과학과                         컴퓨터과학과 복전 추천?
# 43  컴퓨터과학과                                  null
# 44  컴퓨터과학과                   3학년 컴퓨터과학과 컴파일러 ㄱㅊ?
# 45  컴퓨터과학과                                  null
# 46  컴퓨터과학과                                  null
# 47  컴퓨터과학과                                  null
# 48  컴퓨터과학과                                  null
# 49  컴퓨터과학과             컴퓨터과학과 학과장님 성함 아시는분 계신가요?
#
#                                                    내용              날짜 좋아요수
# 0   학교 곳곳에 있는 상명대 출신 교직원 정리스건 김종희 행정,대외부총장님  체육교육 ...     05/07 00:18    4
# 1   컴퓨터과학과 사물함 도둑이 있네요도둑이라 말하기도 뭐하고 거지가 있네요26일 금요일...     04/26 12:12   69
# 2   안녕하십니까 제44대 총학생회장 김정현입니다.2019학년도 제1차 대학평의원회 회의...     04/17 21:39  160
# 3                               컴퓨터과학과입니다 과사에 문의해야하나요     04/05 11:22    0
# 4   저는 컴과 4학년이고 3학기 동안 튜터링 튜터로 참여했습니다.이번 학기도 튜터링을 ...     04/01 20:57    2
# 5   안녕하세요 이번학기에 2학년으로 복학한 16학번 컴퓨터과학과 학생입니다.  저는 제...     04/01 13:26    1
# 6   제1회 축제공모전의 선발 결과가 나왔습니다!우선 참여해주신 많은분들 감사드립니다.수...     03/29 16:28    1
# 7   안녕하세요. 상명대학교 알고리즘 소모임을 만들어보자! 라고 계획한 사람입니다.우선 ...     03/16 16:32    2
# 8   😍<이니로(INYRO) 에서 신입부원을 모집합니다>😍⚠️모집날짜변경 (3.15 금)...     03/04 20:09    3
# 9   😍<이니로(INYRO) 에서 신입부원을 모집합니다>😍안녕하세요~ 상명대학교 학술동아...     02/27 20:10    4
# 10  컴퓨터과학과는 정보와기술의 이해 영역은 이수하지 않아도 됨 이라고 되있는데 이수해도...     02/21 14:19    0
# 11  컴퓨터과학과 1학기 미적분 전선인데 안듣고 다른걸로 채우는건 비추인가요?  미적분이...     02/20 18:00    0
# 12  학교 곳곳에 있는 상명대 출신 교직원 정리스건 김종희 행정,대외부총장님  체육교육 ...     05/07 00:18    4
# 13  컴퓨터과학과 사물함 도둑이 있네요도둑이라 말하기도 뭐하고 거지가 있네요26일 금요일...     04/26 12:12   69
# 14  안녕하십니까 제44대 총학생회장 김정현입니다.2019학년도 제1차 대학평의원회 회의...     04/17 21:39  160
# 15                              컴퓨터과학과입니다 과사에 문의해야하나요     04/05 11:22    0
# 16  저는 컴과 4학년이고 3학기 동안 튜터링 튜터로 참여했습니다.이번 학기도 튜터링을 ...     04/01 20:57    2
# 17  안녕하세요 이번학기에 2학년으로 복학한 16학번 컴퓨터과학과 학생입니다.  저는 제...     04/01 13:26    1
# 18  제1회 축제공모전의 선발 결과가 나왔습니다!우선 참여해주신 많은분들 감사드립니다.수...     03/29 16:28    1
# 19  안녕하세요. 상명대학교 알고리즘 소모임을 만들어보자! 라고 계획한 사람입니다.우선 ...     03/16 16:32    2
# 20  😍<이니로(INYRO) 에서 신입부원을 모집합니다>😍⚠️모집날짜변경 (3.15 금)...     03/04 20:09    3
# 21  😍<이니로(INYRO) 에서 신입부원을 모집합니다>😍안녕하세요~ 상명대학교 학술동아...     02/27 20:10    4
# 22  컴퓨터과학과는 정보와기술의 이해 영역은 이수하지 않아도 됨 이라고 되있는데 이수해도...     02/21 14:19    0
# 23  컴퓨터과학과 1학기 미적분 전선인데 안듣고 다른걸로 채우는건 비추인가요?  미적분이...     02/20 18:00    0
# 24                컴퓨터과학과 미적분 많이 어렵나요? 심화로 나갈까봐 무섭네요..     02/19 19:20    0
# 25    컴퓨터과학과 신입인데요 강의를 미적분이랑 영어중 1개를 선택해서 들을 수 있는건가요?     02/19 19:09    0
# 26                컴퓨터과학과 전선이 파이썬이랑 컴퓨터 기초원리 이 2개인가요??     02/19 12:33    0
# 27                 컴퓨터과학과인데  메모리 8기가  ssd 256기가 어떤가요?     02/19 00:45    0
# 28                          컴퓨터과학과인데 19년형 삼성 북9 어때요?!     02/19 00:43    0
# 29                     컴퓨터과학과 공대인가요? 아니면 자연과학대학인가요..?     02/17 17:06    0
# 30                     컴퓨터과학과 단톡 공지방외에 수다방 같은건 없나요..?     02/16 14:51    0
# 31       노트북 하드디스크 1000이고  메모라 8GB 괜찮나요??  컴퓨터과학과에요!!     02/14 20:15    0
# 32          컴퓨터과학과인데  노트북 추천좀햐주세요 ㅠ용량이나 이런거 어떻게 해야하는지     02/14 19:43    0
# 33  제곧내 ㅠㅠ막 과 공지사항이나 홍보관련 어쩌고저쩌고 올라오는 단톡이요+ 학년단톡.....     02/13 16:36    0
# 34                       원래 컴퓨터과학과는 물리실험 없어요? 기대하고왔는뎅     02/13 01:31    0
# 35  정시러인데 신입생 단톡방이나 컴퓨터과학과 단톡 있나요?그리고 예대관련해서 공지온거 ...     02/11 19:04    0
# 36                                               제곧냉!     02/08 23:14    0
# 37                                              참고하세용     02/07 17:46    0
# 38   컴퓨터과학과인데 컴퓨터 i7까지 돼야하나요?그램 i5 램8기가 뭐 어쩌구 사면 안되나염     02/05 20:40    0
# 39  컴퓨터과학과 수학 많이 어렵나요 1학년1학기때 미적분하고 2학기땐 정수론배운다는데 ...     02/01 15:41    0
# 40                혹시 컴퓨터과학과 취업 현황?같은거 아시는 선배님 계시나요?ㅠㅠ     01/30 23:48    0
# 41  빅데이터과학연계전공이 주관학과인 문헌 정보학과랑 공공인재학부, 경영학부, 글로벌경영...     01/29 20:37    0
# 42                          기초 없으면 어렵나 아예 일학년꺼부터 들을건데     01/27 17:15    0
# 43             컴퓨터과학과는 공학이아니고 자연이던데컴퓨터공학과랑 많이 다르나요 ??     01/24 23:28    0
# 44  이제 3학년 되는데 컴퓨터과학과 컴파일러 들을만 함? 대충 C다 알고있고 자료구조는...     01/18 16:16    0
# 45                   컴퓨터과학과 단톡 없나요?? 아무리 찾아봐도 안보이네욥..     01/04 16:41    0
# 46  컴퓨터과학과 1학년들은 보통 제일 마지막 타임 수업이 몇시쯤에 끝나나요?? 알바때문에ㅠㅠ  18/12/29 20:06    0
# 47       이번에 컴퓨터과학과 들어가는 19학번입니다! 컴퓨터과학과 과잠색 어떤건가요?!?  18/12/28 15:53    0
# 48                        안녕하세요 19학번 컴퓨터과학과 신입생입니다!!!  18/12/20 08:58    0
# 49                                          댓글 달아주세요!  18/12/17 20:24    0

# %%
#모든 교수명 
all_professor = nm_name_list + name_list
#nm_name_list //교양교수명 리스트 총 12명
#name_list //모든 학과 교수명 리스트 총 227명

#교수님별 게시글 관련 정보를 담을 리스트
proboard_like_list = []
proboard_title_list = []
proboard_content_list = []
proboard_pro_list = []
proboard_date_list = []

# %%
pro_page = list() #교수님마다 총 페이지를 담을 리스트
for professor in all_professor:
    page_count = 1
    while(True):
        driver.get(url+professor+p+str(page_count))
        try:
            test1 = driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a')
            test2 = driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next')
            page_count+=1
        except Exception as e:
            pro_page.append(page_count)
            break

# %%
print(len(pro_page))
print(pro_page)
# Out:
# 239
# [7, 11, 3, 5, 17, 13, 2, 4, 7, 11, 2, 4, 2, 4, 3, 7, 2, 3, 3, 2, 5, 2, 3, 8, 6, 4, 5, 1, 2, 2, 1, 1, 4, 4, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 3, 4, 5, 3, 2, 2, 3, 7, 3, 5, 3, 3, 2, 10, 3, 5, 7, 7, 7, 11, 5, 4, 4, 4, 4, 11, 4, 4, 6, 5, 4, 4, 4, 3, 2, 2, 2, 3, 4, 4, 2, 5, 3, 3, 5, 4, 2, 3, 3, 3, 10, 9, 4, 4, 1, 1, 1, 2, 2, 2, 1, 2, 2, 2, 2, 3, 2, 3, 4, 3, 2, 2, 2, 2, 3, 2, 2, 2, 3, 2, 1, 2, 3, 14, 3, 3, 12, 2, 2, 2, 2, 2, 4, 6, 5, 2, 2, 7, 2, 1, 2, 2, 2, 3, 5, 3, 3, 2, 4, 4, 4, 1, 2, 2, 2, 1, 2, 2, 2, 2, 1, 2, 2, 1, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 2, 2, 2, 2, 8, 2, 1, 2, 1, 2, 3, 2, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 7, 2, 2, 1, 2, 1, 1, 2, 1, 2, 2, 2, 2, 2, 1, 2, 2, 1, 2, 2, 8, 2, 2, 2, 1, 1, 1, 1, 3, 6, 3]

# %%
pro_page_index = 0
for professor in all_professor:
    page_count = 1
    while(True) :
        print('현재 '+professor+'교수님의 '+str(page_count)+'페이지입니다.')
        if page_count == pro_page[pro_page_index]:
            print(professor+'교수님의 마지막 페이지네요. 글이 없습니다. 다음 교수님으로 넘어갑니다.')
            pro_page_index+=1
            break
        driver.get(url+professor+p+str(page_count))
        driver.implicitly_wait(3)
        time.sleep(2)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser') 
        print('크롤링 중...')
        everytime_link = list()
        content = list()
        content = soup.findAll('article') #해당 페이지의 게시물들
        for u in content: #페이지의 게시글 url을 가져온다.
            find_url = u.find('a', attrs={'class', 'article'}).get('href') #url 가져오기
            everytime_link.append(find_url) #url 저장
        for l in everytime_link: #가져온 url
            try:
                driver.get('https://everytime.kr'+l)
                time.sleep(3)
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')           
                try:
                    title = soup.find('h2', attrs={'class', 'large'}).get_text()     
                except Exception as e:
                    title = 'null'
                contents = soup.find('p', attrs={'class', 'large'})
                date = soup.find('time', attrs={'class', 'large'})
                like = soup.find('li', attrs={'class','vote'})  
                proboard_pro_list.append(professor)
                proboard_title_list.append(title)
                proboard_content_list.append(contents.get_text())
                proboard_like_list.append(like.text.strip())
                proboard_date_list.append(date.get_text()) 
            except Exception as e:
                continue  
        print(professor+' '+str(page_count)+'페이지의 게시글 개수')
        print(len(proboard_pro_list)) 
        print(len(proboard_title_list))
        print(len(proboard_content_list))
        print(len(proboard_date_list)) #date
        print(len(proboard_like_list))#like
        page_count+=1
# Out:
# 현재 프란시스브래넌교수님의 1페이지입니다.
# 크롤링 중...
# 프란시스브래넌 1페이지의 게시글 개수
# 12
# 12
# 12
# 12
# 12
# 현재 프란시스브래넌교수님의 2페이지입니다.
# 크롤링 중...
# 프란시스브래넌 2페이지의 게시글 개수
# 30
# 30
# 30
# 30
# 30
# 현재 프란시스브래넌교수님의 3페이지입니다.
# 크롤링 중...
# 프란시스브래넌 3페이지의 게시글 개수
# 50
# 50
# 50
# 50
# 50
# 현재 프란시스브래넌교수님의 4페이지입니다.
# 크롤링 중...
# 프란시스브래넌 4페이지의 게시글 개수
# 70
# 70
# 70
# 70
# 70
# 현재 프란시스브래넌교수님의 5페이지입니다.
# 크롤링 중...
# 프란시스브래넌 5페이지의 게시글 개수
# 90
# 90
# 90
# 90
# 90
# 현재 프란시스브래넌교수님의 6페이지입니다.
# 크롤링 중...
# 프란시스브래넌 6페이지의 게시글 개수
# 95
# 95
# 95
# 95
# 95
# 현재 프란시스브래넌교수님의 7페이지입니다.
# 프란시스브래넌교수님의 마지막 페이지네요. 글이 없습니다. 다음 교수님으로 넘어갑니다.
# 현재 홍세령교수님의 1페이지입니다.
# 크롤링 중...
# 홍세령 1페이지의 게시글 개수
# 106
# 106
# 106
# 106
# 106
# 현재 홍세령교수님의 2페이지입니다.
# 크롤링 중...
# 홍세령 2페이지의 게시글 개수
# 125
# 125
# 125
# 125
# 125
# 현재 홍세령교수님의 3페이지입니다.
# 크롤링 중...
# 홍세령 3페이지의 게시글 개수
# 141
# 141
# 141
# 141
# 141
# 현재 홍세령교수님의 4페이지입니다.
# 크롤링 중...
# 홍세령 4페이지의 게시글 개수
# 161
# 161
# 161
# 161
# 161
# 현재 홍세령교수님의 5페이지입니다.
# 크롤링 중...
# 홍세령 5페이지의 게시글 개수
# 181
# 181
# 181
# 181
# 181
# 현재 홍세령교수님의 6페이지입니다.
# 크롤링 중...
# 홍세령 6페이지의 게시글 개수
# 201
# 201
# 201
# 201
# 201
# 현재 홍세령교수님의 7페이지입니다.
# 크롤링 중...
# 홍세령 7페이지의 게시글 개수
# 221
# 221
# 221
# 221
# 221
# 현재 홍세령교수님의 8페이지입니다.
# 크롤링 중...
# 홍세령 8페이지의 게시글 개수
# 241
# 241
# 241
# 241
# 241
# 현재 홍세령교수님의 9페이지입니다.
# 크롤링 중...
# 홍세령 9페이지의 게시글 개수
# 261
# 261
# 261
# 261
# 261
# 현재 홍세령교수님의 10페이지입니다.
# 크롤링 중...
# 홍세령 10페이지의 게시글 개수
# 272
# 272
# 272
# 272
# 272
# 현재 홍세령교수님의 11페이지입니다.
# 홍세령교수님의 마지막 페이지네요. 글이 없습니다. 다음 교수님으로 넘어갑니다.
# 현재 전영옥교수님의 1페이지입니다.
# 크롤링 중...
# 전영옥 1페이지의 게시글 개수
# 284
# 284
# 284
# 284
# 284
# 현재 전영옥교수님의 2페이지입니다.
# 크롤링 중...
# 전영옥 2페이지의 게시글 개수
# 302
# 302
# 302
# 302
# 302
# 현재 전영옥교수님의 3페이지입니다.
# 전영옥교수님의 마지막 페이지네요. 글이 없습니다. 다음 교수님으로 넘어갑니다.
# 현재 김인주교수님의 1페이지입니다.
# 크롤링 중...
# 김인주 1페이지의 게시글 개수
# 309
# 309
# 309
# 309
# 309
# 현재 김인주교수님의 2페이지입니다.
# 크롤링 중...
# 김인주 2페이지의 게시글 개수
# 329
# 329
# 329
# 329
# 329
# 현재 김인주교수님의 3페이지입니다.
# 크롤링 중...
# 김인주 3페이지의 게시글 개수
# 347
# 347
# 347
# 347
# 347
# 현재 김인주교수님의 4페이지입니다.
# 크롤링 중...
# 김인주 4페이지의 게시글 개수
# 360
# 360
# 360
# 360
# 360
# 현재 김인주교수님의 5페이지입니다.
# 김인주교수님의 마지막 페이지네요. 글이 없습니다. 다음 교수님으로 넘어갑니다.
# 현재 심예지교수님의 1페이지입니다.
# 크롤링 중...
# 심예지 1페이지의 게시글 개수
# 372
# 372
# 372
# 372
# 372
# 현재 심예지교수님의 2페이지입니다.
# 크롤링 중...
# 심예지 2페이지의 게시글 개수
# 388
# 388
# 388
# 388
# 388
# 현재 심예지교수님의 3페이지입니다.
# 크롤링 중...
# 심예지 3페이지의 게시글 개수
# 400
# 400
# 400
# 400
# 400
# 현재 심예지교수님의 4페이지입니다.
# 크롤링 중...
# 심예지 4페이지의 게시글 개수
# 409
# 409
# 409
# 409
# 409
# 현재 심예지교수님의 5페이지입니다.
# 크롤링 중...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-97bef7218d8a> in <module>
#      23             try:
#      24                 driver.get('https://everytime.kr'+l)
# ---> 25                 time.sleep(3)
#      26                 html = driver.page_source
#      27                 soup = BeautifulSoup(html, 'html.parser')
#
# KeyboardInterrupt:

# %%
p = pd.DataFrame()
p['학과/교양']= proboard_pro_list
p['타이틀']=proboard_title_list
p['내용']=proboard_content_list
p['날짜']=proboard_date_list
p['좋아요수']=proboard_like_list
p.head(100)
# Out:
#       학과/교양                                       타이틀  \
# 0   프란시스브래넌                  프란시스브래넌 교수님 34분반 시험기간 수업
# 1   프란시스브래넌                             프란시스브래넌교수님 결석
# 2   프란시스브래넌                                      null
# 3   프란시스브래넌                                      null
# 4   프란시스브래넌                  프란시스브래넌 교수님 한국어 못하는거 아니지
# 5   프란시스브래넌                            금12 프란시스브래넌교수님
# 6   프란시스브래넌                                   교선질문이요!
# 7   프란시스브래넌                                      null
# 8   프란시스브래넌                                      null
# 9   프란시스브래넌                                    영어 이러닝
# 10  프란시스브래넌                                    영어18분반
# 11  프란시스브래넌                       프란시스브래넌 교수님 뭐하시는분이죠
# 12  프란시스브래넌                               프란시스브래넌 교수님
# 13  프란시스브래넌                           프란시스브래넌교수님 11분반
# 14  프란시스브래넌                     프란시스브래넌 교수님 목요일 영어 수업
# 15  프란시스브래넌                     ㅋㅋ 영어 싸강 프란시스브래넌 교수님꺼
# 16  프란시스브래넌                         오늘 프란시스브래넌교수님꺼 싸강
# 17  프란시스브래넌                   프란시스브래넌 교수님 사이버 강의 어때요?
# 18  프란시스브래넌    English through cultural understanding
# 19  프란시스브래넌                   프란시스브래넌 알쓸신잡 다들 어떻게 나왔냐
# 20  프란시스브래넌                            영어 프란시스브래넌 교수님
# 21  프란시스브래넌                                      null
# 22  프란시스브래넌                            프란시스브래넌 교수님 인강
# 23  프란시스브래넌                                      null
# 24  프란시스브래넌                            혹시프란시스브래넌교수님인강
# 25  프란시스브래넌                                      null
# 26  프란시스브래넌                                프란시스브래넌 인강
# 27  프란시스브래넌                                      null
# 28  프란시스브래넌  프란시스브래넌교수님 english enrichment 들을만하겠죠...?
# 29  프란시스브래넌                    프란시스브래넌 이메일 아시는 분 있나요?
# ..      ...                                       ...
# 70  프란시스브래넌                                      null
# 71  프란시스브래넌                                      null
# 72  프란시스브래넌                                      null
# 73  프란시스브래넌                                      null
# 74  프란시스브래넌                                      null
# 75  프란시스브래넌                                      null
# 76  프란시스브래넌                                      null
# 77  프란시스브래넌                                      null
# 78  프란시스브래넌                                      null
# 79  프란시스브래넌                                      null
# 80  프란시스브래넌                                      null
# 81  프란시스브래넌                                      null
# 82  프란시스브래넌                                      null
# 83  프란시스브래넌                                      null
# 84  프란시스브래넌                                      null
# 85  프란시스브래넌                                      null
# 86  프란시스브래넌                                      null
# 87  프란시스브래넌                                      null
# 88  프란시스브래넌                                      null
# 89  프란시스브래넌                                      null
# 90  프란시스브래넌                                      null
# 91  프란시스브래넌                                      null
# 92  프란시스브래넌                                      null
# 93  프란시스브래넌                                      null
# 94  프란시스브래넌                                      null
# 95      홍세령                         과기환 홍세령교수님 2분반 시험
# 96      홍세령                                       과기환
# 97      홍세령                      홍세령 교수님 강의들은 다 발표있던데
# 98      홍세령                  홍세령교수님 수업은 전부 발표,토론 하나요?
# 99      홍세령                과기환(홍세령 교수님)VS생과이(유하영 교수님)
#
#                                                    내용              날짜 좋아요수
# 0                          하시나요? 들었던거 같은데 기억이 안나네요ㅠㅠㅜ     04/20 20:41    0
# 1                          결석2번했고 둘다 공결서있는데 처리해주시나요??     04/10 16:52    0
# 2                프란시스브래넌 교수님 영어 원고 쓴거 이캠 어디다가 올려야 되죠?     04/01 15:29    0
# 3   프란시스브래넌교수님 발표하능거 signposting 이거 어떻게 해야하는지 모르겠어...     03/27 00:50    0
# 4   수업은 완전 싹다 영어로 하시는데 중간중간에연기하시면서 쓰는 한국어 들어보면 무조건...     03/19 14:35    1
# 5                                      발표 준비해야하는건가요 ?     03/19 13:15    0
# 6   English Enrichment(Listening) 프란시스브래넌 교수님꼬 신청했...     02/22 10:36    0
# 7                             프란시스브래넌 교수님 영어수업 괜찮나요?!     02/08 01:59    0
# 8   새내기들아 영어 화이팅해~!!😊 갠적으로 심예지,박지혜,이연숙,프란시스브래넌, 정희...     01/31 22:32    8
# 9                         프란시스브래넌 3학점짜리 인강 수강신청 치열하냐?     01/24 23:01    0
# 10                영어18분반 프란시스브래넌 교수님 내일 목요일 보강하는 건가요?  18/12/12 14:16    0
# 11                                        너무 잘생기셧는데..  18/11/14 19:12    4
# 12  English Enrichnent 인강 중간고사 점수 다들 떴어?난 왜 내 점수가 ...  18/11/12 09:08    0
# 13     에세이 Final draft때 스크린샷 포함하라는게 정확히 뭐 찍으라는거에요..??  18/10/14 22:32    0
# 14                        이번주 수업 휴강 맞죠?다음주가 휴강인거 아니죠?  18/09/25 00:11    0
# 15                                         할꺼 개많네  ㄷㄷ  18/09/05 22:12    0
# 16                                            ot 안했죠?  18/09/03 23:59    0
# 17                         인강 안보고 강의자료만 달달외워서 a+가능해요?  18/08/02 10:07    0
# 18                이거 싸강인가요?프란시스브래넌교수님이 가르치시는걸로 알고있습니다  18/07/22 14:50    0
# 19                                           씨쁠실화냐...  18/07/01 19:28    0
# 20                                  glc 얼마나 가야되는건가요??  18/04/18 14:51    0
# 21  프란시스브래넌 교수님 수업들으시는분들 발표 수업시작하셨나요?? 발표 날짜 정한 이후...  18/04/08 12:00    0
# 22                문화수업이라기보다는 <프란시스브래넌과 함께하는 알쓸신잡느낌>이야  18/03/31 10:02    0
# 23  프리즘2 19분반 프란시스브래넌교수님 수업 그거 사이트 들어가서 하는거 방법 어디서...  18/03/15 13:33    0
# 24                          월요일 싸강코스모스로 들어도 출석인정 되나요?  18/03/13 10:13    0
# 25  영어 18분반 프란시스브래넌 교수님 수업 숙제있었나요..? 책만 준비 해오라고하셨던...  18/03/12 23:26    0
# 26                      english enrichment 오티 가는건가요?!  18/03/05 13:20    0
# 27                             영어 프란시스브래넌 교수님은 어떠세요??  18/02/23 13:24    0
# 28                              강의평가가 아예없네요 ㅋㅋㅋ   ㅠㅠㅠ  18/02/01 10:32    0
# 29                         프란시스브래넌 교수님 이메일 아시는 분 있나요?  17/12/01 22:32    0
# ..                                                ...             ...  ...
# 70  영어교육과 학생중에... 전공과창업버리고 프란시스브래넌 교수님의 사이버강의 들으실 ...  15/08/09 15:53    0
# 71                        프란시스브래넌 교수님 어떤가요~두개나 듣게 됐는데  15/08/06 11:07    0
# 72               안전빵으로 프란시스브래넌 새로운 인강 신청했는데 불안하다 괜찮을지  15/08/06 10:29    0
# 73  프란시스브래넌 교수님이랑 로첼 안드레아 서로이 교수님 어떄요??? 영어4 들어보려구하는데  15/07/29 11:14    2
# 74  프란시스브래넌 교수님 온라인 워크북 기한 얘기해주셨어요???? 얘기해주셨으면 언제까...  15/06/13 16:36    1
# 75  프란시스브래넌교수님 화요일1교시 수업 중간고사 평소랑 같은시간에 같은강의실 (N30...  15/04/19 22:52    1
# 76  프란시스브래넌교수님 중간고사시험 어떻게내시는지아시는분ㅜㅜㅜ?  뭘공부해야할지 아예모...  15/04/08 14:15    0
# 77  프란시스브래넌 교수님 영어1 수 12수업 four corners 온라안 워크북 클래...  15/03/09 20:52    1
# 78  영어1 프란시스브래넌 교수님 강의 들으신분 있나요? 과제하려면 어떤 홈페이지 가입하...  15/03/04 19:22    0
# 79                                     프란시스브래넌 까다로움 ?  14/11/26 10:41    0
# 80  낼 프란시스브래넌 영어2 숙제잇어요? 저번주에 워크북 검사햇어요? 아님 낼 하는건가 ㅠㅠ  14/10/06 18:21    1
# 81                  영어 프란시스브래넌 교수님꺼 들으시는분?ㅠ 과제 있었나요?ㅠ  14/09/23 17:29    1
# 82  프란시스브래넌 영어2 낼 수업인데 걍 교재만 챙겨가면 되나여? 따로 과제나 참고할만...  14/09/10 18:29    1
# 83             프란시스브래넌교수 영어2 정정기간에 넣었는데 오티 내용좀 알려주세요~  14/09/06 16:58    0
# 84                                영어2 프란시스브래넌 수업 어때요?  14/09/05 11:29    0
# 85  프란시스브래넌교수님수업 하나 들으러 수요일에학교가야하는데 같은레벨인 다른요일로 바꿀...  14/09/03 00:06    1
# 86                                   프란시스브래넌 교수님 어때요?  14/09/02 19:21    0
# 87               프란시스브래넌 수업어때요? ㅠㅠㅠㅠ들어보신부 답변부탁드려요ㅠㅠㅠㅠ  14/08/07 11:22    0
# 88                              프란시스브래넌교수님 어떠세요 ??ㅠㅠㅠ  14/07/30 01:44    0
# 89           영어1 34교시 프란시스브래넌인가 내일 강의실 n202맞나요 ???ㅠ ㅜ  14/06/22 15:30    0
# 90                              프란시스브래넌오픈마인드 숙제 검사 함?  14/03/26 08:15    2
# 91               영어1 프란시스브래넌교수님 준비물이나 교재좀 알려주실수잇나요ㅠㅠ?  14/03/09 18:30    0
# 92              영어1 프란시스브래넌 교수님수업 교재나 준비물 뭔지 말씀해주셧나요?  14/03/08 17:46    0
# 93  나다니엘코어드교수님이나 프란시스브래넌교수님 월/화수업하시는 분중에 금요일로 영어바꾸...  14/03/07 09:27    0
# 94                        프란시스브래넌 영어2 월욜에 워크북 제출이에여??  13/10/19 02:17    0
# 95                       23일 3시 맞나요? 누구는 25일이라고 하고...     04/16 23:24    0
# 96                           시험범위 좀 알려줘요ㅠㅠㅠㅠ홍세령 교수님이요     04/14 23:06    0
# 97  조는 어떻게 편성하나요?학생들끼리 알아서 만드는건지아님 교수님이 직접 편성하는건지 ...     03/05 18:33    0
# 98  구체적으로 어떤방식인지 좀 알고싶은데한학기동안 발표 몇번이나 하는지,토론이나 조별과...     03/03 13:34    0
# 99      과학기술과 환경이랑 생명과학의 이해 둘중에 뭐 듣는게 좋을까요?? 도와주세요ㅠㅠㅠ     02/21 21:32    0
#
# [100 rows x 5 columns]
